# %%
import numpy as np
import torch
from transformers import BertTokenizer, BertForSequenceClassification, BertForMaskedLM
import re

# %%
from sentence_transformers import SentenceTransformer, util

# %%
# 加载同义词集
cos_sim = np.load('cos_sim_counter_fitting.npy')

# %%
# 选择最相似的同义词
def pick_most_similar_words_batch(src_words, sim_mat, idx2word, ret_count=10, threshold=0.):
    """
    Given a list of source words (their indices), a similarity matrix, and an index-to-word mapping,
    this function returns the top `ret_count` similar words for each source word, filtered by a given threshold.
    
    Parameters:
    - src_words: List of source word indices.
    - sim_mat: Similarity matrix of shape (vocab_size, vocab_size).
    - idx2word: A mapping from word index to actual word.
    - ret_count: Number of top similar words to return for each source word.
    - threshold: A similarity threshold to filter out words.
    
    Returns:
    - sim_words: A list of lists containing similar words for each source word.
    - sim_values: A list of lists containing similarity values for each word in sim_words.
    """
    
    # 对于每个src_word，找到其与其他所有单词的相似度排名（从高到低）
    sim_order = np.argsort(-sim_mat[src_words, :])[:, 1:1 + ret_count]
    
    sim_words, sim_values = [], []  # 初始化列表以保存结果

    # 遍历src_words的每个词
    for idx, src_word in enumerate(src_words):
        # 获取对应src_word的相似度值
        sim_value = sim_mat[src_word][sim_order[idx]]
        
        # 根据阈值筛选出大于等于threshold的相似度值
        mask = sim_value >= threshold
        
        # 使用mask获取单词和其相似度值
        sim_word, sim_value = sim_order[idx][mask], sim_value[mask]
        
        # 将单词索引转换为实际的单词
        sim_word = [idx2word[id] for id in sim_word]
        
        # 保存结果
        sim_words.append(sim_word)
        sim_values.append(sim_value)

    return sim_words, sim_values  # 返回相似单词及其相似度值

# %%
# 计算影响最大的词
def influential_tokens(sentence, model, tokenizer, k=5):
    # 确保模型在评估模式
    model.eval()

    # 获取原始logit输出
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        original_logits = model(**inputs).logits

    # 为每个token计算logit差异
    token_ids = inputs["input_ids"][0].tolist()  # 获取token ids
    tokens = [tokenizer.decode([token_id]) for token_id in token_ids]  # 转换为tokens
    diffs = []

    for i, token_id in enumerate(token_ids):
        # 如果是[CLS], [SEP]或[PAD]，则跳过
        if token_id in [tokenizer.cls_token_id, tokenizer.sep_token_id, tokenizer.pad_token_id]:
            continue

        # 将当前token替换为[MASK]
        masked_input_ids = inputs["input_ids"].clone()
        masked_input_ids[0][i] = tokenizer.mask_token_id

        # 获取mask后的logits
        with torch.no_grad():
            masked_logits = model(input_ids=masked_input_ids, attention_mask=inputs["attention_mask"]).logits

        # 计算logit差异
        diff = torch.abs(original_logits - masked_logits).sum().item()
        diffs.append((tokens[i], i, diff))  # 保存token, index和差异值

    # 根据差异大小排序tokens
    sorted_tokens = sorted(diffs, key=lambda x: x[2], reverse=True)

    # 返回前k个token及其索引
    return [(token_info[0], token_info[1]) for token_info in sorted_tokens[:k]]

# %%
# 正则表达式去掉特殊字符
def extract_words(sentence):
    words = re.findall(r'\b\w+\b', sentence)
    return ' '.join(words)

# %%
# 加载模型

# 窃取的模型
model_path = '/home/ubuntu/zhc/work/adversarial_output'
tokenizer = BertTokenizer.from_pretrained(model_path)
model = BertForSequenceClassification.from_pretrained(model_path)

sentence = "This is by far the worst customer service place in the country. Good selection but sometimes I'll rather pay more elsewhere to avoid the employees there"
sentence = extract_words(sentence)
# print(len(sentence))
k = 10

top_k_tokens_and_indices = influential_tokens(sentence, model, tokenizer, k)

# %%
# topk个影响最大的词
top_k_tokens_and_indices
# Out:
# [('worst', 6),
#  ('customer', 7),
#  ('place', 9),
#  ('service', 8),
#  ('by', 3),
#  ('the', 25),
#  ('avoid', 24),
#  ('this', 1),
#  ('to', 23),
#  ('is', 2)]

# %%
def get_token_from_encoded(sentence, index, tokenizer):
    token_ids = tokenizer.encode(sentence, add_special_tokens=True)
    token = tokenizer.decode([token_ids[index]])
    return token


perturb_idxes = []
words_perturb = []
for i in range(k):
    perturb_idxes.append(top_k_tokens_and_indices[i][1])
    words_perturb.append(top_k_tokens_and_indices[i][0])

# %%
perturb_idxes, words_perturb #得到替换词下标和词
# Out:
# ([6, 7, 9, 8, 3, 25, 24, 1, 23, 2],
#  ['worst',
#   'customer',
#   'place',
#   'service',
#   'by',
#   'the',
#   'avoid',
#   'this',
#   'to',
#   'is'])

# %%
idx2word = {}
word2idx = {}

print("Building vocab...")
with open('./counter-fitted-vectors.txt', 'r') as ifile:
    for line in ifile:
        word = line.split()[0]
        if word not in idx2word:
            idx2word[len(idx2word)] = word
            word2idx[word] = len(idx2word) - 1
# Out:
# Building vocab...

# %%
words_perturb_idx = [word2idx[word] for word in words_perturb if word in word2idx]

# %%
words_perturb_idx # 同义词典的位置
# Out:
# [29711, 43347, 45368, 361, 52770, 20088, 55632, 51532, 33735, 24167]

# %%
words_perturb = [(idx, idx2word[idx]) for idx in words_perturb_idx]
words_perturb
# Out:
# [(29711, 'worst'),
#  (43347, 'customer'),
#  (45368, 'place'),
#  (361, 'service'),
#  (52770, 'by'),
#  (20088, 'the'),
#  (55632, 'avoid'),
#  (51532, 'this'),
#  (33735, 'to'),
#  (24167, 'is')]

# %%
synonym_words, _ = pick_most_similar_words_batch(words_perturb_idx, cos_sim, idx2word, 20, 0.5)

# %%
# 得到top20同义词
synonym_words
# Out:
# [['lousiest',
#   'worse',
#   'meanest',
#   'pire',
#   'gravest',
#   'hardest',
#   'trickiest',
#   'roughest',
#   'harshest',
#   'toughest',
#   'biggest',
#   'grandest',
#   'strongest',
#   'greatest',
#   'hugest',
#   'strictest',
#   'shittiest',
#   'largest',
#   'ugliest',
#   'finest'],
#  ['client',
#   'clients',
#   'customers',
#   'consumers',
#   'clientele',
#   'users',
#   'shoppers',
#   'buyers',
#   'user',
#   'patrons',
#   'guests',
#   'subscribers',
#   'subscriber',
#   'consumer',
#   'beneficiaries',
#   'beneficiary',
#   'recipients',
#   'diners',
#   'receivers',
#   'recipient'],
#  ['placing',
#   'mise',
#   'stead',
#   'platz',
#   'site',
#   'putting',
#   'venue',
#   'situ',
#   'location',
#   'placement',
#   'locations',
#   'spot',
#   'plaza',
#   'placements',
#   'places',
#   'put',
#   'positioning',
#   'scene',
#   'pleasure',
#   'loco'],
#  ['servicing', 'services', 'serving', 'serve', 'serves', 'department'],
#  ['per',
#   'para',
#   'paras',
#   'par',
#   'here',
#   'via',
#   'at',
#   'pair',
#   'through',
#   'for',
#   'torque',
#   'under',
#   'doublet',
#   'with',
#   'during',
#   'across',
#   'travers',
#   'into',
#   'throughout',
#   'in'],
#  ['du',
#   'to',
#   'de',
#   'nova',
#   'per',
#   'el',
#   'los',
#   'of',
#   'la',
#   'las',
#   'al',
#   'le',
#   'from',
#   'for',
#   'del',
#   'pour',
#   'angeles',
#   'in',
#   'among',
#   'at'],
#  ['avoiding',
#   'avoided',
#   'avert',
#   'averted',
#   'stave',
#   'forestall',
#   'preventing',
#   'evade',
#   'avoidance',
#   'shirk',
#   'prevent',
#   'sidestep',
#   'circumvent',
#   'evita',
#   'avoids',
#   'dodged',
#   'shunned',
#   'elude',
#   'bypass',
#   'bypassing'],
#  ['cette',
#   'that',
#   'ce',
#   'ec',
#   'such',
#   'say',
#   'tell',
#   'esa',
#   'said',
#   'dis',
#   'says',
#   'told',
#   'these',
#   'telling',
#   'tells',
#   'ey',
#   'saying'],
#  ['pour',
#   'of',
#   'aux',
#   'for',
#   'de',
#   'the',
#   'towards',
#   'per',
#   'toward',
#   'al',
#   'in',
#   'du',
#   'into',
#   'from',
#   'dans',
#   'at',
#   'among',
#   'onto',
#   'd',
#   'en'],
#  ['exists',
#   'poses',
#   'represents',
#   'comes',
#   'constitutes',
#   'es',
#   'ai',
#   'becoming',
#   'becomes',
#   'are',
#   'makes',
#   'entails',
#   'se',
#   'become',
#   'constitute',
#   'resides',
#   'gets',
#   'got',
#   'does',
#   'goes']]

# %%
synonym_words[0]
# Out:
# ['lousiest',
#  'worse',
#  'meanest',
#  'pire',
#  'gravest',
#  'hardest',
#  'trickiest',
#  'roughest',
#  'harshest',
#  'toughest',
#  'biggest',
#  'grandest',
#  'strongest',
#  'greatest',
#  'hugest',
#  'strictest',
#  'shittiest',
#  'largest',
#  'ugliest',
#  'finest']

# %%
# 1. 加载预训练的BERT模型和tokenizer
model_name = "bert-base-uncased"
model = BertForMaskedLM.from_pretrained(model_name)
tokenizer = BertTokenizer.from_pretrained(model_name)
model.eval()

def mask_sentence(sentence, mask_idx, tokenizer):
    """Inserts a [MASK] token at the specified index of the sentence."""
    tokens = tokenizer.tokenize(sentence)
    tokens[mask_idx] = '[MASK]'
    return tokenizer.convert_tokens_to_string(tokens)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
word_mask_probability_list = []

for index, idx in enumerate(perturb_idxes):    
    msk_sentence = mask_sentence(sentence, mask_idx=idx-1, tokenizer=tokenizer)

    print(idx,msk_sentence)
    
    inputs = tokenizer(msk_sentence, return_tensors="pt")
    mask_idx = torch.where(inputs["input_ids"][0] == tokenizer.mask_token_id)[0].item()
    # 3. 使用BERT预测[MASK]位置的概率分布
    with torch.no_grad():
        outputs = model(**inputs)
        predictions = outputs.logits[0, mask_idx].softmax(dim=0)

    word_mask_probability = {}
    
    for word in synonym_words[index]:
        word_id = tokenizer.convert_tokens_to_ids(word)
        word_probability = predictions[word_id].item()
        word_mask_probability[word] = word_probability
        # print(word_mask_probability)
    # print("---")
    
    total_value = sum(word_mask_probability.values())
    normalized_data = {k: v / total_value for k, v in word_mask_probability.items()}

    word_mask_probability_list.append(normalized_data)
# Out:
# 6 this is by far the [MASK] customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# 7 this is by far the worst [MASK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# 9 this is by far the worst customer service [MASK] in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# 8 this is by far the worst customer [MASK] place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# 3 this is [MASK] far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# 25 this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [MASK] employees there
# 24 this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to [MASK] the employees there
# 1 [MASK] is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# 23 this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere [MASK] avoid the employees there
# 2 this [MASK] by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there

# %%
word_mask_probability_list
# Out:
# [{'lousiest': 3.36199143199791e-06,
#   'worse': 0.00029483650906247347,
#   'meanest': 3.36199143199791e-06,
#   'pire': 3.36199143199791e-06,
#   'gravest': 3.36199143199791e-06,
#   'hardest': 0.007192660904432566,
#   'trickiest': 3.36199143199791e-06,
#   'roughest': 3.36199143199791e-06,
#   'harshest': 3.36199143199791e-06,
#   'toughest': 3.36199143199791e-06,
#   'biggest': 0.36415523862722426,
#   'grandest': 3.36199143199791e-06,
#   'strongest': 0.00652603025452569,
#   'greatest': 0.005930805948555896,
#   'hugest': 3.36199143199791e-06,
#   'strictest': 3.36199143199791e-06,
#   'shittiest': 3.36199143199791e-06,
#   'largest': 0.5721295179169974,
#   'ugliest': 3.36199143199791e-06,
#   'finest': 0.04372720395058579},
#  {'client': 0.07052511201904697,
#   'clients': 0.005505798024715439,
#   'customers': 0.24449151609369407,
#   'consumers': 0.05662476344170525,
#   'clientele': 0.0015177043687120927,
#   'users': 0.011127843131108182,
#   'shoppers': 0.0015177043687120927,
#   'buyers': 0.0037192539655181754,
#   'user': 0.05164231703283972,
#   'patrons': 0.0033554997098534252,
#   'guests': 0.060236920719073876,
#   'subscribers': 0.0012316112127013603,
#   'subscriber': 0.0015177043687120927,
#   'consumer': 0.4813439726986423,
#   'beneficiaries': 0.0015177043687120927,
#   'beneficiary': 0.0015177043687120927,
#   'recipients': 9.023210711966213e-05,
#   'diners': 0.0015177043687120927,
#   'receivers': 4.462427817987086e-05,
#   'recipient': 0.0009543093535291492},
#  {'placing': 0.0016700566868591438,
#   'mise': 0.00010503259014908118,
#   'stead': 0.00010503259014908118,
#   'platz': 0.00010503259014908118,
#   'site': 0.5989393284749502,
#   'putting': 0.00012669687185183357,
#   'venue': 0.07113855199128333,
#   'situ': 5.577911329321921e-06,
#   'location': 0.2332029654132997,
#   'placement': 0.031765786708261357,
#   'locations': 0.005190366639053774,
#   'spot': 0.033317811731932795,
#   'plaza': 0.006001359722433956,
#   'placements': 0.00010503259014908118,
#   'places': 0.005599772200064622,
#   'put': 0.000934335542914724,
#   'positioning': 0.00011698618670076102,
#   'scene': 0.011459171470604849,
#   'pleasure': 9.635913964157717e-05,
#   'loco': 1.474294822166893e-05},
#  {'servicing': 0.20110078200592657,
#   'services': 0.4365642387376764,
#   'serving': 0.2814512349249864,
#   'serve': 0.057680687549522686,
#   'serves': 0.014890643368074389,
#   'department': 0.008312413413813533},
#  {'per': 0.00027784841683226367,
#   'para': 0.00010284520761974289,
#   'paras': 3.560511447984961e-05,
#   'par': 1.3188211202041206e-05,
#   'here': 0.0008957841505902764,
#   'via': 0.10713325091891249,
#   'at': 0.5022568244767142,
#   'pair': 2.4669717117490126e-05,
#   'through': 0.015473224245154942,
#   'for': 0.25164685675822823,
#   'torque': 8.756531467108409e-07,
#   'under': 0.0011876677174281866,
#   'doublet': 3.560511447984961e-05,
#   'with': 0.006626375991759623,
#   'during': 0.0009892305440192164,
#   'across': 0.0007591408872805964,
#   'travers': 7.98519760936715e-06,
#   'into': 0.0004338989563038104,
#   'throughout': 0.0007859952589662568,
#   'in': 0.1113131274621549},
#  {'du': 0.0005848271511732134,
#   'to': 0.2024509668022062,
#   'de': 0.006078744279045407,
#   'nova': 4.022819421161001e-05,
#   'per': 0.004240310027631988,
#   'el': 0.0005036493847801863,
#   'los': 0.005645898584958056,
#   'of': 0.044026993476738455,
#   'la': 0.0021908160988560353,
#   'las': 0.003490183280376772,
#   'al': 0.0028819492531677177,
#   'le': 0.0011929426746448933,
#   'from': 0.5755552868213754,
#   'for': 0.08925037317734788,
#   'del': 0.0002237812063955388,
#   'pour': 8.121169950999333e-06,
#   'angeles': 1.2928946391976822e-05,
#   'in': 0.03288003449106839,
#   'among': 0.018533421107235274,
#   'at': 0.010208543872444025},
#  {'avoiding': 0.005639804281527288,
#   'avoided': 0.0013218903744537957,
#   'avert': 0.0035273243976614846,
#   'averted': 0.0035273243976614846,
#   'stave': 0.0035273243976614846,
#   'forestall': 0.0035273243976614846,
#   'preventing': 0.0004715584179409451,
#   'evade': 0.07911749164694742,
#   'avoidance': 0.0010045646629301406,
#   'shirk': 0.0035273243976614846,
#   'prevent': 0.4521406071307623,
#   'sidestep': 0.0035273243976614846,
#   'circumvent': 0.0035273243976614846,
#   'evita': 0.0035273243976614846,
#   'avoids': 0.0005404268319755361,
#   'dodged': 0.002083337422242668,
#   'shunned': 0.0035273243976614846,
#   'elude': 0.0035273243976614846,
#   'bypass': 0.41887975085694357,
#   'bypassing': 0.0035273243976614846},
#  {'cette': 0.0028531863758557217,
#   'that': 0.8891188658215685,
#   'ce': 0.0008944925676116785,
#   'ec': 0.00044709510856190366,
#   'such': 0.004885867181418619,
#   'say': 0.001779353641039091,
#   'tell': 0.00045061636507804536,
#   'esa': 0.00036482975320354316,
#   'said': 0.0014581380297906358,
#   'dis': 0.0028531863758557217,
#   'says': 0.0005590826687694606,
#   'told': 0.00010859563924146196,
#   'these': 0.09103256469790975,
#   'telling': 4.201734293105975e-05,
#   'tells': 0.00010428680847062351,
#   'ey': 0.0028531863758557217,
#   'saying': 0.00019463524683843478},
#  {'pour': 1.465400944285697e-05,
#   'of': 0.03636574517092475,
#   'aux': 4.597073420163413e-06,
#   'for': 0.3872957949345058,
#   'de': 0.004164181295929191,
#   'the': 0.1490732297115971,
#   'towards': 0.054917233866612195,
#   'per': 0.0028956894103964047,
#   'toward': 0.007583931771433836,
#   'al': 0.0005371444458874628,
#   'in': 0.17192375815565553,
#   'du': 0.0001987430775809352,
#   'into': 0.05142452334013866,
#   'from': 0.05776612072798823,
#   'dans': 6.01827693714089e-05,
#   'at': 0.061457070542055896,
#   'among': 0.0005038921038676877,
#   'onto': 0.006457937516531487,
#   'd': 0.004330740769694022,
#   'en': 0.0030248293069664377},
#  {'exists': 0.0026743500795829937,
#   'poses': 0.0002662573752352518,
#   'represents': 0.04363721318563216,
#   'comes': 0.0026749468249982295,
#   'constitutes': 0.01067928657466514,
#   'es': 0.00017207598039202358,
#   'ai': 5.891598771616494e-06,
#   'becoming': 0.0028714334281781137,
#   'becomes': 0.08075719028844598,
#   'are': 0.10225248408157603,
#   'makes': 0.6791412297717251,
#   'entails': 5.1998366133711354e-05,
#   'se': 4.5712016552113764e-05,
#   'become': 0.00331504742969374,
#   'constitute': 0.001327359453949214,
#   'resides': 0.00016319630969774683,
#   'gets': 0.02828233468406928,
#   'got': 0.01992804918629321,
#   'does': 0.02029688446517578,
#   'goes': 0.0014570588992325968}]

# %%
def replace_token_at_index(sentence, index, replacement_word, tokenizer):
    token_ids = tokenizer.encode(sentence, add_special_tokens=False)
    replacement_ids = tokenizer.encode(replacement_word, add_special_tokens=False)
    
    if len(replacement_ids) != 1:
        # 将replacement_word设置为"[UNK]"标记
        replacement_word = "[UNK]"
        replacement_ids = tokenizer.encode(replacement_word, add_special_tokens=False)
    
    token_ids[index] = replacement_ids[0]
    return tokenizer.decode(token_ids)


def generate_nested_sentences(sentence, indices, replacement_words_nested_list, tokenizer):
    if len(indices) != len(replacement_words_nested_list):
        raise ValueError("Length of indices and replacement words nested list should be the same.")
    
    nested_sentences = []
    for idx, replacement_words_list in zip(indices, replacement_words_nested_list):
        modified_sentences_for_idx = []
        for replacement_word in replacement_words_list:
            modified_sentence = replace_token_at_index(sentence, idx, replacement_word, tokenizer)
            modified_sentences_for_idx.append(modified_sentence)
        nested_sentences.append(modified_sentences_for_idx)
    return nested_sentences

indices = perturb_idxes
replacement_words_nested_list = synonym_words

nested_sentences = generate_nested_sentences(sentence, indices, replacement_words_nested_list, tokenizer)

for i, sentences_for_index in enumerate(nested_sentences):
    print(f"For index {indices[i]}:")
    for modified_sentence in sentences_for_index:
        print(f"  - {modified_sentence}")
# Out:
# For index 6:
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst worse service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst hardest service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst biggest service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst strongest service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst greatest service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst largest service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst [UNK] service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst finest service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# For index 7:
#   - this is by far the worst customer client place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer clients place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer customers place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer consumers place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer [UNK] place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer users place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer [UNK] place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer buyers place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer user place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer patrons place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer guests place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer subscribers place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer [UNK] place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer consumer place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer [UNK] place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer [UNK] place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer recipients place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer [UNK] place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer receivers place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer recipient place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# For index 9:
#   - this is by far the worst customer service place placing the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place [UNK] the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place [UNK] the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place [UNK] the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place site the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place putting the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place venue the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place situ the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place location the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place placement the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place locations the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place spot the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place plaza the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place [UNK] the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place places the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place put the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place positioning the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place scene the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place pleasure the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service place loco the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# For index 8:
#   - this is by far the worst customer service servicing in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service services in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service serving in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service serve in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service serves in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by far the worst customer service department in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# For index 3:
#   - this is by per the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by para the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by [UNK] the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by par the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by here the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by via the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by at the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by pair the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by through the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by for the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by torque the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by under the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by [UNK] the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by with the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by during the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by across the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by travers the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by into the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by throughout the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is by in the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# For index 25:
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the du there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the to there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the de there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the nova there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the per there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the el there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the los there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the of there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the la there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the las there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the al there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the le there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the from there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the for there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the del there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the pour there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the angeles there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the in there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the among there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the at there
# For index 24:
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid avoiding employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid avoided employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid preventing employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid evade employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid avoidance employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid prevent employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid avoids employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid dodged employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid bypass employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid [UNK] employees there
# For index 1:
#   - this [UNK] by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this that by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this ce by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this ec by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this such by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this say by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this tell by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this esa by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this said by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this [UNK] by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this says by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this told by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this these by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this telling by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this tells by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this [UNK] by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this saying by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
# For index 23:
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to pour the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to of the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to aux the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to for the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to de the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to the the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to towards the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to per the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to toward the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to al the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to in the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to du the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to into the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to from the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to dans the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to at the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to among the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to onto the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to d the employees there
#   - this is by far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to en the employees there
# For index 2:
#   - this is exists far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is poses far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is represents far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is comes far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is constitutes far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is es far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is ai far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is becoming far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is becomes far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is are far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is makes far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is [UNK] far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is se far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is become far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is constitute far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is resides far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is gets far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is got far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is does far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there
#   - this is goes far the worst customer service place in the country good selection but sometimes i ll rather pay more elsewhere to avoid the employees there

# %%
model = SentenceTransformer('bert-base-nli-mean-tokens')


word_similarity_list = []
# 对单一句子进行编码
query_embedding = model.encode(sentences=sentence, convert_to_tensor=True)

for i in range(len(nested_sentences)):
    # 对多个句子进行编码
    sentence_embeddings = model.encode(nested_sentences[i], convert_to_tensor=True)
        
    # 计算相似度
    similarity_scores = util.pytorch_cos_sim(query_embedding, sentence_embeddings)
    similarity_scores = similarity_scores.to('cpu').numpy().reshape(-1)
    
    word_similarity_probability = {}
    for idx, word in enumerate(synonym_words[i]):    # break
        word_similarity_probability[word] = similarity_scores[idx]
    total_value = sum(word_similarity_probability.values())
    normalized_data = {k: v / total_value for k, v in word_similarity_probability.items()}

    word_similarity_list.append(normalized_data)

# %%
word_similarity_list
# Out:
# [{'lousiest': 0.050281814278912554,
#   'worse': 0.05015069382778549,
#   'meanest': 0.050281814278912554,
#   'pire': 0.050281814278912554,
#   'gravest': 0.050281814278912554,
#   'hardest': 0.04946358667217611,
#   'trickiest': 0.050281814278912554,
#   'roughest': 0.050281814278912554,
#   'harshest': 0.050281814278912554,
#   'toughest': 0.050281814278912554,
#   'biggest': 0.049070851525799423,
#   'grandest': 0.050281814278912554,
#   'strongest': 0.049538524803608035,
#   'greatest': 0.05000881538350827,
#   'hugest': 0.050281814278912554,
#   'strictest': 0.050281814278912554,
#   'shittiest': 0.050281814278912554,
#   'largest': 0.04802518614299593,
#   'ugliest': 0.050281814278912554,
#   'finest': 0.05007875601826349},
#  {'client': 0.05008598147882964,
#   'clients': 0.05006311607325184,
#   'customers': 0.0500539195519733,
#   'consumers': 0.04999016739599157,
#   'clientele': 0.04994412483835196,
#   'users': 0.0500473848660583,
#   'shoppers': 0.04994412483835196,
#   'buyers': 0.05006863458553143,
#   'user': 0.05017268596969721,
#   'patrons': 0.049975437374621706,
#   'guests': 0.04964086145577383,
#   'subscribers': 0.05002704340797611,
#   'subscriber': 0.04994412483835196,
#   'consumer': 0.05005415036427397,
#   'beneficiaries': 0.04994412483835196,
#   'beneficiary': 0.04994412483835196,
#   'recipients': 0.050001624079279244,
#   'diners': 0.04994412483835196,
#   'receivers': 0.05003919552572813,
#   'recipient': 0.05011504884090199},
#  {'placing': 0.05010831020909555,
#   'mise': 0.04981346838107622,
#   'stead': 0.04981346838107622,
#   'platz': 0.04981346838107622,
#   'site': 0.050194850167608614,
#   'putting': 0.050077067934468596,
#   'venue': 0.05011014975807301,
#   'situ': 0.05000883629755961,
#   'location': 0.05020122546725107,
#   'placement': 0.050245416723895826,
#   'locations': 0.0501792170070992,
#   'spot': 0.05006616289575909,
#   'plaza': 0.05005210777971563,
#   'placements': 0.04981346838107622,
#   'places': 0.049979102934022,
#   'put': 0.050164218070175154,
#   'positioning': 0.049904694380203424,
#   'scene': 0.05015914127569325,
#   'pleasure': 0.04921551877783492,
#   'loco': 0.050080106797240176},
#  {'servicing': 0.16668419539492604,
#   'services': 0.16665390112558767,
#   'serving': 0.16673040462603664,
#   'serve': 0.16674091488274587,
#   'serves': 0.1665678047722409,
#   'department': 0.16662277919846288},
#  {'per': 0.049912481321831834,
#   'para': 0.05014907102598079,
#   'paras': 0.04995375794522762,
#   'par': 0.05016392026794683,
#   'here': 0.050230487805175035,
#   'via': 0.049840309616345946,
#   'at': 0.04992282077174502,
#   'pair': 0.05005811753985877,
#   'through': 0.04998215760904848,
#   'for': 0.049946897048251206,
#   'torque': 0.050012715959998635,
#   'under': 0.0500923167962596,
#   'doublet': 0.04995375794522762,
#   'with': 0.05000999505212675,
#   'during': 0.049721413458664425,
#   'across': 0.0498894332779137,
#   'travers': 0.05002094783375912,
#   'into': 0.050075832003042386,
#   'throughout': 0.05003705079791585,
#   'in': 0.05002651592368038},
#  {'du': 0.05008462953317459,
#   'to': 0.05001867070919314,
#   'de': 0.05001804885290948,
#   'nova': 0.049910708046766235,
#   'per': 0.050056721103825544,
#   'el': 0.04990596451501789,
#   'los': 0.04991036857932636,
#   'of': 0.05000716787001365,
#   'la': 0.049949912029866886,
#   'las': 0.04997502961628102,
#   'al': 0.050025387958711386,
#   'le': 0.05000702667559176,
#   'from': 0.04999830266280062,
#   'for': 0.05000435900225893,
#   'del': 0.04998006755341971,
#   'pour': 0.050066394423793674,
#   'angeles': 0.049877953945023215,
#   'in': 0.05006538202974732,
#   'among': 0.05008366820945105,
#   'at': 0.05005423668282752},
#  {'avoiding': 0.050186859757610676,
#   'avoided': 0.05022900267004723,
#   'avert': 0.049924983243221775,
#   'averted': 0.049924983243221775,
#   'stave': 0.049924983243221775,
#   'forestall': 0.049924983243221775,
#   'preventing': 0.049985885037576706,
#   'evade': 0.050016597225616626,
#   'avoidance': 0.05000899276051619,
#   'shirk': 0.049924983243221775,
#   'prevent': 0.05003481550575061,
#   'sidestep': 0.049924983243221775,
#   'circumvent': 0.049924983243221775,
#   'evita': 0.049924983243221775,
#   'avoids': 0.05023220423394813,
#   'dodged': 0.05008293507124793,
#   'shunned': 0.049924983243221775,
#   'elude': 0.049924983243221775,
#   'bypass': 0.05004789206224639,
#   'bypassing': 0.049924983243221775},
#  {'cette': 0.058862949009787835,
#   'that': 0.05900139207131137,
#   'ce': 0.05885134503338605,
#   'ec': 0.05896365091448633,
#   'such': 0.058980012238877666,
#   'say': 0.058782427012955954,
#   'tell': 0.05862989189614886,
#   'esa': 0.05872979973311913,
#   'said': 0.05884398314324793,
#   'dis': 0.058862949009787835,
#   'says': 0.058807561903446694,
#   'told': 0.05865017415052267,
#   'these': 0.05909694135875117,
#   'telling': 0.05868244506299772,
#   'tells': 0.05864756960837409,
#   'ey': 0.058862949009787835,
#   'saying': 0.058743958843010854},
#  {'pour': 0.04971195458858421,
#   'of': 0.05000674127287191,
#   'aux': 0.0500581966331639,
#   'for': 0.050033406018861415,
#   'de': 0.05014132451619873,
#   'the': 0.05003678490571554,
#   'towards': 0.0500235267107924,
#   'per': 0.04993939666687163,
#   'toward': 0.050048489902649276,
#   'al': 0.049878543399057056,
#   'in': 0.04998615912875511,
#   'du': 0.05009900062790678,
#   'into': 0.04995353288794861,
#   'from': 0.050101816366951886,
#   'dans': 0.049999568707497874,
#   'at': 0.04995334517201227,
#   'among': 0.04993104936305727,
#   'onto': 0.050025249458659785,
#   'd': 0.05002833466090383,
#   'en': 0.0500435790115405},
#  {'exists': 0.049967694833780996,
#   'poses': 0.04996407093586419,
#   'represents': 0.050053645798728584,
#   'comes': 0.05004431396259133,
#   'constitutes': 0.05007289252388574,
#   'es': 0.050080325700635885,
#   'ai': 0.05003617514235244,
#   'becoming': 0.049914589181222935,
#   'becomes': 0.05001878521637543,
#   'are': 0.05003386984095486,
#   'makes': 0.04986478151497035,
#   'entails': 0.04993633256872376,
#   'se': 0.04998231301605431,
#   'become': 0.04997464362813632,
#   'constitute': 0.050039694389751845,
#   'resides': 0.04998733026085992,
#   'gets': 0.050029316048440596,
#   'got': 0.05003561899960283,
#   'does': 0.049976948929533895,
#   'goes': 0.04998665750753378}]

# %%
import math 
combined_probs = []
for dict1, dict2 in zip(word_similarity_list, word_mask_probability_list):
    combined_dict = {}
    for token in dict1:
        combined_dict[token] = math.log(dict1[token]) + math.log(dict2[token])
    combined_probs.append(combined_dict)

# %%
combined_probs
# Out:
# [{'lousiest': -15.593088883865258,
#   'worse': -11.121812491440904,
#   'meanest': -15.593088883865258,
#   'pire': -15.593088883865258,
#   'gravest': -15.593088883865258,
#   'hardest': -7.941212594542692,
#   'trickiest': -15.593088883865258,
#   'roughest': -15.593088883865258,
#   'harshest': -15.593088883865258,
#   'toughest': -15.593088883865258,
#   'biggest': -4.024665098260676,
#   'grandest': -15.593088883865258,
#   'strongest': -8.036961078072004,
#   'greatest': -8.123151146251256,
#   'hugest': -15.593088883865258,
#   'strictest': -15.593088883865258,
#   'shittiest': -15.593088883865258,
#   'largest': -3.5944195776835803,
#   'ugliest': -15.593088883865258,
#   'finest': -6.123943246921323},
#  {'client': -5.645800554583403,
#   'clients': -8.196424303842848,
#   'customers': -4.403229133232981,
#   'consumers': -5.8672378177903095,
#   'clientele': -9.487406771153351,
#   'users': -7.493089946247938,
#   'shoppers': -9.487406771153351,
#   'buyers': -8.588592700836353,
#   'user': -5.955698349607361,
#   'patrons': -8.69337822160054,
#   'guests': -5.812410778409823,
#   'subscribers': -9.694623589391766,
#   'subscriber': -9.487406771153351,
#   'consumer': -3.72582299679504,
#   'beneficiaries': -9.487406771153351,
#   'beneficiary': -9.487406771153351,
#   'recipients': -12.308825031965046,
#   'diners': -9.487406771153351,
#   'receivers': -13.012181163373075,
#   'recipient': -9.947956609062695},
#  {'placing': -9.388466121112126,
#   'mise': -12.160709755690373,
#   'stead': -12.160709755690373,
#   'platz': -12.160709755690373,
#   'site': -3.5044378178678572,
#   'putting': -11.96790526189002,
#   'venue': -5.636657568451002,
#   'situ': -15.092251728602513,
#   'location': -4.4475619492903045,
#   'placement': -6.440201403735583,
#   'locations': -8.253105282786853,
#   'spot': -6.396073028524871,
#   'plaza': -8.110459875649772,
#   'placements': -12.160709755690373,
#   'places': -8.181179662863684,
#   'put': -9.968128224480468,
#   'positioning': -12.05109489741702,
#   'scene': -7.461519370320174,
#   'pleasure': -12.258974591747492,
#   'loco': -14.118877095824644},
#  {'servicing': -3.395603395957715,
#   'services': -2.620655812154628,
#   'serving': -3.059173193936182,
#   'serve': -4.644146945140955,
#   'serves': -5.99937504174591,
#   'department': -6.582028118151093},
#  {'per': -11.185919036988082,
#   'para': -12.175040827427,
#   'paras': -13.239678807839654,
#   'par': -14.228646448618893,
#   'here': -10.008944187206707,
#   'via': -5.232613075933028,
#   'at': -3.6859207382442243,
#   'pair': -13.604504691912554,
#   'through': -7.1647334019633195,
#   'for': -4.376523433340672,
#   'torque': -16.94377376235041,
#   'under': -9.729651436311153,
#   'doublet': -13.239678807839654,
#   'with': -8.01222962429549,
#   'during': -9.91990272966907,
#   'across': -10.181269232159933,
#   'travers': -14.733234433647574,
#   'into': -10.736915652977173,
#   'throughout': -10.14355132941525,
#   'in': -5.1906101766552375},
#  {'du': -10.438235336179467,
#   'to': -4.592616490076201,
#   'de': -8.098328499019036,
#   'nova': -13.118462168752016,
#   'per': -8.457717387134846,
#   'el': -10.591244951107496,
#   'los': -8.174352422242347,
#   'of': -6.118541271491491,
#   'la': -9.120215691743187,
#   'las': -8.654032834253359,
#   'al': -8.844513033005624,
#   'le': -9.72692393836619,
#   'from': -3.5481862088517873,
#   'for': -5.411954774381102,
#   'del': -11.400972742577347,
#   'pour': -14.71544159747652,
#   'angeles': -14.254218032598011,
#   'in': -6.409315146972693,
#   'among': -6.982239938281914,
#   'at': -7.579178402554508},
#  {'avoiding': -8.169907960296687,
#   'avoided': -9.619855141686939,
#   'avert': -8.644449391756355,
#   'averted': -8.644449391756355,
#   'stave': -8.644449391756355,
#   'forestall': -8.644449391756355,
#   'preventing': -10.65548217814989,
#   'evade': -5.532221679441068,
#   'avoidance': -9.898753437046317,
#   'shirk': -8.644449391756355,
#   'prevent': -3.788798275552014,
#   'sidestep': -8.644449391756355,
#   'circumvent': -8.644449391756355,
#   'evita': -8.644449391756355,
#   'avoids': -10.514250240411581,
#   'dodged': -9.167859087482324,
#   'shunned': -8.644449391756355,
#   'elude': -8.644449391756355,
#   'bypass': -3.8649462817908944,
#   'bypassing': -8.644449391756355},
#  {'cette': -8.691862317940634,
#   'that': -2.9477185859961694,
#   'ce': -9.85199455429075,
#   'ec': -10.543573326281857,
#   'such': -8.151965158102225,
#   'say': -9.165417432704096,
#   'tell': -10.541404824049469,
#   'esa': -10.750887762185561,
#   'said': -9.363460670297664,
#   'dis': -8.691862317940634,
#   'says': -10.322698037403232,
#   'told': -11.964044040153679,
#   'these': -5.225114092224895,
#   'telling': -12.91304275681696,
#   'tells': -12.004574824391801,
#   'ey': -8.691862317940634,
#   'saying': -11.3789502395074},
#  {'pour': -14.132306417660917,
#   'of': -6.309725471338266,
#   'aux': -15.284659687681739,
#   'for': -3.9436309261759237,
#   'de': -8.474145360532034,
#   'the': -4.898314465129151,
#   'towards': -5.897189915950285,
#   'per': -8.841477133364867,
#   'toward': -7.876486455903877,
#   'al': -10.52740787357141,
#   'in': -4.756713296277127,
#   'du': -11.517251853454905,
#   'into': -5.964302160417206,
#   'from': -5.845050838448593,
#   'dans': -12.71386536912667,
#   'at': -5.786082193598904,
#   'among': -10.590260630444787,
#   'onto': -8.037672693896791,
#   'd': -8.437182413994591,
#   'en': -8.795761689469208},
#  {'exists': -8.920427474750575,
#   'poses': -11.227498254050182,
#   'represents': -6.126504911973083,
#   'comes': -8.918672164152802,
#   'constitutes': -7.533724732514911,
#   'es': -11.661701480831308,
#   'ai': -15.036992191137438,
#   'becoming': -8.850385872163322,
#   'becomes': -5.511664916809453,
#   'are': -5.275365296222542,
#   'makes': -3.385366483002091,
#   'entails': -12.861304693958775,
#   'se': -12.989235426193874,
#   'become': -8.705522877470617,
#   'constitute': -9.619502383905566,
#   'resides': -11.71654242828276,
#   'gets': -6.56066400975172,
#   'got': -6.91064718000924,
#   'does': -6.893481280601069,
#   'goes': -9.527334486594995}]

# %%
import heapq

def k_best_viterbi(probs, k=1):
    # 初始化路径
    paths = [(score, [token]) for token, score in probs[0].items()]
    
    for i in range(1, len(probs)):
        new_paths = []
        for prev_score, prev_path in paths:
            for next_token, next_score in probs[i].items():
                new_score = prev_score + next_score
                heapq.heappush(new_paths, (new_score, prev_path + [next_token]))
                if len(new_paths) > k:
                    heapq.heappop(new_paths)
        paths = new_paths
        
    return sorted(paths, key=lambda x: x[0], reverse=True)


all_paths = k_best_viterbi(combined_probs, k=1000)
for score, path in all_paths:
    print(path, score)
# Out:
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -34.74495742232332
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -34.8211054285622
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.17520294290041
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.183474804104875
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -35.251350949139294
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -35.25962281034375
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.42236355876126
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -35.43556011741977
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -35.49851156500013
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -35.511708123658636
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.51990500612641
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -35.55803979242452
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -35.596053012365275
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.613720324681964
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -35.634187798663405
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.68808155374576
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -35.689868330920845
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -35.69964096127654
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -35.76422955998464
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -35.775788967515425
# ['largest', 'consumer', 'site', 'services', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -35.78938770354773
# ['biggest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.85260907933835
# ['largest', 'customers', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.86088094054281
# ['largest', 'consumer', 'site', 'services', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -35.8655357097866
# ['biggest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -35.86580563799686
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -35.87407749920132
# ['biggest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -35.92875708557723
# ['largest', 'customers', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -35.937028946781695
# ['biggest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -35.94195364423574
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -35.950150526703496
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -35.9502255054402
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -35.98828531300161
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -35.996557174206075
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.02629853294238
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.06443331924049
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.072705180444956
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.11296625385771
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.11832707432286
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.12659893552731
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.129886481853646
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.138158343058095
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.18911426009659
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.19447508056173
# ['largest', 'customers', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.197311142564345
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.20274694176619
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.20603448809253
# ['largest', 'consumer', 'site', 'servicing', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.21050770122285
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.214306349296976
# ['biggest', 'consumer', 'site', 'services', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.21963322412482
# ['largest', 'consumer', 'site', 'serving', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.22790508532928
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.23544592886246
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -36.24864248752097
# ['largest', 'consumer', 'site', 'services', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -36.24964686073433
# ['largest', 'customers', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.27345914880323
# ['largest', 'consumer', 'site', 'servicing', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.28665570746173
# ['biggest', 'customers', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.2911264611199
# ['largest', 'consumer', 'site', 'services', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -36.29164976001212
# ['biggest', 'consumer', 'site', 'services', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -36.2957812303637
# ['largest', 'consumer', 'site', 'serving', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -36.304053091568164
# ['biggest', 'consumer', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.30432301977841
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.31159393510134
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -36.32479049375985
# ['largest', 'consumer', 'site', 'services', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -36.32579486697321
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.33298737622761
# ['largest', 'customers', 'location', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.3654876901837
# ['biggest', 'customers', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.36727446735878
# ['largest', 'consumer', 'site', 'services', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -36.367797766251
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.37704709771448
# ['largest', 'consumer', 'location', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.378684248842205
# ['biggest', 'consumer', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.38047102601729
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'the', 'makes'] -36.39024365637299
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.40913538246649
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.42680269478316
# ['largest', 'customers', 'location', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.44163569642258
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.45319510395336
# ['largest', 'consumer', 'location', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.45483225508109
# ['largest', 'consumer', 'location', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.463029137548844
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'the', 'makes'] -36.46639166261187
# ['largest', 'customers', 'site', 'services', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.46679383998567
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.47458854507963
# ['largest', 'consumer', 'site', 'services', 'for', 'to', 'prevent', 'that', 'for', 'makes'] -36.479990398644176
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'evade', 'that', 'for', 'makes'] -36.488380826212364
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.50116392384696
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.502950701022044
# ['largest', 'consumer', 'location', 'servicing', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.539177143787725
# ['largest', 'customers', 'site', 'services', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -36.54294184622455
# ['biggest', 'customers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.543211774434795
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.55073655131851
# ['largest', 'customers', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.55148363563926
# ['largest', 'consumer', 'site', 'services', 'for', 'to', 'bypass', 'that', 'for', 'makes'] -36.55613840488306
# ['biggest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.556844456104415
# ['largest', 'consumer', 'site', 'servicing', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.564335287350815
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.5684038636352
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.57731193008584
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'at', 'makes'] -36.5874086897463
# ['largest', 'consumer', 'site', 'services', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -36.60247007364893
# ['largest', 'consumer', 'site', 'services', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -36.60872598785262
# ['biggest', 'customers', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.619359780673676
# ['biggest', 'customers', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.62755666314143
# ['largest', 'customers', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.62763164187814
# ['biggest', 'consumer', 'location', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.632992462343296
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'are'] -36.63495623554377
# ['largest', 'consumer', 'site', 'servicing', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -36.640483293589696
# ['biggest', 'consumer', 'site', 'servicing', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.64075322179994
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.642765092698994
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.64455186987408
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'from', 'makes'] -36.64637733459598
# ['biggest', 'consumer', 'site', 'serving', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.658150605906386
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'at', 'makes'] -36.66355669598518
# ['largest', 'client', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.66493498011168
# ['biggest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.66569144943955
# ['largest', 'customers', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.67396331064401
# ['largest', 'consumer', 'site', 'services', 'at', 'to', 'bypass', 'that', 'in', 'makes'] -36.67861807988781
# ['biggest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -36.678888008098056
# ['biggest', 'consumer', 'site', 'services', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -36.67989238131142
# ['largest', 'consumer', 'site', 'services', 'at', 'for', 'bypass', 'that', 'for', 'makes'] -36.684873994091504
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -36.68715986930252
# ['largest', 'consumer', 'site', 'serving', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -36.68816424251588
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'towards', 'makes'] -36.698516412097675
# ['biggest', 'customers', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.703704669380315
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'are'] -36.71110424178265
# ['biggest', 'consumer', 'site', 'servicing', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.71690122803882
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.718913098937875
# ['biggest', 'consumer', 'site', 'services', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -36.72189528058921
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'from', 'makes'] -36.72252534083486
# ['largest', 'consumer', 'site', 'serving', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -36.73016714179367
# ['largest', 'consumer', 'location', 'services', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.73251183497018
# ['biggest', 'consumer', 'site', 'serving', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -36.73429861214525
# ['largest', 'client', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.74108298635056
# ['biggest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.74183945567843
# ['largest', 'consumer', 'site', 'services', 'at', 'to', 'prevent', 'that', 'the', 'makes'] -36.74407124250095
# ['largest', 'customers', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.750111316882894
# ['biggest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -36.75503601433694
# ['biggest', 'consumer', 'site', 'services', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -36.7560403875503
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.763232896804695
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -36.7633078755414
# ['largest', 'consumer', 'site', 'serving', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -36.76431224875476
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'into', 'makes'] -36.7656286565646
# ['largest', 'consumer', 'site', 'serve', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.76844855530965
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'towards', 'makes'] -36.774664418336556
# ['biggest', 'customers', 'location', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.7957332107608
# ['biggest', 'consumer', 'site', 'services', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -36.79804328682809
# ['largest', 'customers', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.804005071965264
# ['largest', 'consumer', 'site', 'serving', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -36.80631514803255
# ['biggest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.807292618291584
# ['largest', 'consumer', 'location', 'services', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -36.80865984120905
# ['biggest', 'consumer', 'location', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.80892976941931
# ['largest', 'customers', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.81556447949605
# ['largest', 'consumer', 'location', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.81720163062377
# ['largest', 'consumer', 'site', 'services', 'at', 'to', 'bypass', 'that', 'the', 'makes'] -36.82021924873983
# ['biggest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'the', 'makes'] -36.82048917695009
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'the', 'makes'] -36.82876103815455
# ['largest', 'guests', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.831545203938106
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -36.839380903043576
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'into', 'makes'] -36.84177666280348
# ['largest', 'consumer', 'site', 'serve', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.844596561548514
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'becomes'] -36.87125585613068
# ['biggest', 'customers', 'location', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.87188121699968
# ['largest', 'consumer', 'venue', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.87717717290646
# ['largest', 'customers', 'location', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.88015307820413
# ['biggest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.883440624530465
# ['biggest', 'consumer', 'location', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.88507777565819
# ['largest', 'consumers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.88637224331859
# ['largest', 'customers', 'site', 'servicing', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.88791383766079
# ['largest', 'customers', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.89171248573493
# ['biggest', 'consumer', 'location', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.89327465812595
# ['largest', 'consumer', 'location', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.89334963686264
# ['biggest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'the', 'makes'] -36.89663718318897
# ['biggest', 'customers', 'site', 'services', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.89703936056277
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -36.90483406565673
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'the', 'makes'] -36.904909044393435
# ['largest', 'customers', 'site', 'serving', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.90531122176722
# ['largest', 'guests', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.90769321017697
# ['biggest', 'consumer', 'site', 'services', 'for', 'to', 'prevent', 'that', 'for', 'makes'] -36.91023591922128
# ['largest', 'consumer', 'site', 'serving', 'for', 'to', 'prevent', 'that', 'for', 'makes'] -36.91850778042573
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'evade', 'that', 'for', 'makes'] -36.918626346789466
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -36.926048623958906
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'evade', 'that', 'for', 'makes'] -36.92689820799393
# ['largest', 'customers', 'site', 'services', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -36.92705299717227
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.93140944442406
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -36.939681305628525
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'becomes'] -36.94740386236956
# ['largest', 'consumer', 'venue', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.95332517914534
# ['largest', 'consumers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.96252024955746
# ['largest', 'customers', 'site', 'servicing', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -36.96406184389967
# ['largest', 'customers', 'site', 'services', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -36.96905589645006
# ['biggest', 'consumer', 'location', 'servicing', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -36.96942266436483
# ['biggest', 'customers', 'site', 'services', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -36.97318736680164
# ['largest', 'user', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -36.97483277513564
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -36.98098207189561
# ['largest', 'customers', 'site', 'serving', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -36.9814592280061
# ['biggest', 'customers', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -36.98172915621636
# ['biggest', 'consumer', 'site', 'services', 'for', 'to', 'bypass', 'that', 'for', 'makes'] -36.986383925460146
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -36.99458080792792
# ['largest', 'consumer', 'site', 'serving', 'for', 'to', 'bypass', 'that', 'for', 'makes'] -36.99465578666461
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -37.00219663019779
# ['largest', 'customers', 'site', 'services', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -37.00320100341115
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.007557450662944
# ['largest', 'customers', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -37.010393512665544
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.01582931186741
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'at', 'makes'] -37.017654210323386
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'these', 'for', 'makes'] -37.02235292855204
# ['largest', 'consumer', 'site', 'servicing', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -37.02359007132405
# ['largest', 'consumer', 'site', 'servicing', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -37.02459444453741
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'at', 'makes'] -37.02592607152785
# ['biggest', 'consumer', 'site', 'services', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -37.03271559422602
# ['biggest', 'consumer', 'site', 'services', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -37.038971508429725
# ['largest', 'consumer', 'site', 'serving', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -37.04098745543048
# ['largest', 'customers', 'site', 'services', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -37.04520390268894
# ['largest', 'consumer', 'site', 'serving', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -37.04724336963419
# ['largest', 'user', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.05098078137452
# ['largest', 'customers', 'location', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -37.05609038528016
# ['biggest', 'customers', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -37.05787716245523
# ['largest', 'consumer', 'site', 'services', 'in', 'from', 'prevent', 'that', 'in', 'makes'] -37.06272923083553
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'are'] -37.065201756120864
# ['largest', 'consumer', 'site', 'servicing', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -37.066597343815204
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'the', 'makes'] -37.06764979281094
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -37.070728814166785
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -37.07301061327608
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'are'] -37.07347361732532
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'from', 'makes'] -37.076622855173085
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -37.081282474480545
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'from', 'makes'] -37.08489471637753
# ['largest', 'customers', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.086541518904426
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'at', 'makes'] -37.09380221656227
# ['biggest', 'client', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.09518050068877
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'these', 'for', 'makes'] -37.09850093479092
# ['largest', 'consumer', 'site', 'servicing', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -37.09973807756293
# ['largest', 'consumer', 'site', 'servicing', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -37.100742450776295
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'at', 'makes'] -37.10207407776673
# ['largest', 'client', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.10345236189323
# ['biggest', 'customers', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -37.104208831221115
# ['largest', 'consumer', 'site', 'services', 'via', 'from', 'prevent', 'that', 'in', 'makes'] -37.10473213011332
# ['biggest', 'consumer', 'site', 'services', 'at', 'to', 'bypass', 'that', 'in', 'makes'] -37.1088636004649
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'of', 'makes'] -37.111051967485665
# ['biggest', 'consumer', 'site', 'services', 'at', 'for', 'bypass', 'that', 'for', 'makes'] -37.115119514668606
# ['largest', 'consumer', 'site', 'serving', 'at', 'to', 'bypass', 'that', 'in', 'makes'] -37.11713546166936
# ['biggest', 'consumer', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -37.11740538987962
# ['biggest', 'consumer', 'site', 'serving', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -37.118409763092984
# ['largest', 'consumer', 'site', 'serving', 'at', 'for', 'bypass', 'that', 'for', 'makes'] -37.123391375873055
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'towards', 'makes'] -37.12876193267478
# ['largest', 'customers', 'location', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -37.132238391519024
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'towards', 'makes'] -37.137033793879226
# ['largest', 'consumer', 'site', 'services', 'in', 'from', 'bypass', 'that', 'in', 'makes'] -37.13887723707441
# ['largest', 'customers', 'location', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.140435273986796
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'are'] -37.141349762359745
# ['largest', 'consumer', 'site', 'servicing', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -37.142745350054085
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'bypass', 'that', 'the', 'makes'] -37.14379779904982
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -37.149158619514964
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'are'] -37.1496216235642
# ['largest', 'customers', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -37.15199468151758
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'from', 'makes'] -37.152770861411966
# ['largest', 'consumer', 'location', 'servicing', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -37.1536318326453
# ['largest', 'customers', 'site', 'services', 'for', 'to', 'prevent', 'that', 'for', 'makes'] -37.157396535082114
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -37.15743048071943
# ['biggest', 'consumer', 'site', 'serving', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -37.160412662370774
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'from', 'makes'] -37.161042722616415
# ['biggest', 'consumer', 'location', 'services', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -37.16275735554727
# ['largest', 'consumer', 'site', 'servicing', 'for', 'from', 'prevent', 'that', 'the', 'makes'] -37.165191240176085
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'evade', 'that', 'for', 'makes'] -37.165786962650316
# ['largest', 'consumer', 'location', 'serving', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -37.171029216751734
# ['biggest', 'client', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.17132850692765
# ['biggest', 'consumer', 'site', 'services', 'at', 'to', 'prevent', 'that', 'the', 'makes'] -37.17431676307805
# ['largest', 'customers', 'location', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -37.17857006028491
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'evade', 'that', 'for', 'makes'] -37.17898352130882
# ['largest', 'client', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.179600368132114
# ['biggest', 'customers', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.180356837459996
# ['largest', 'consumer', 'site', 'services', 'via', 'from', 'bypass', 'that', 'in', 'makes'] -37.1808801363522
# ['largest', 'consumer', 'site', 'serving', 'at', 'to', 'prevent', 'that', 'the', 'makes'] -37.182588624282516
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'of', 'makes'] -37.187199973724546
# ['largest', 'consumer', 'location', 'services', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -37.19176661894342
# ['largest', 'consumer', 'location', 'services', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -37.19277099215678
# ['biggest', 'consumer', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -37.1935533961185
# ['biggest', 'consumer', 'site', 'serving', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -37.19455776933185
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'into', 'makes'] -37.19587417714169
# ['biggest', 'consumer', 'site', 'serve', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.198694075886735
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'into', 'makes'] -37.20414603834615
# ['largest', 'consumer', 'site', 'services', 'in', 'from', 'prevent', 'that', 'the', 'makes'] -37.204330399687564
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'towards', 'makes'] -37.20490993891366
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'towards', 'makes'] -37.21318180011811
# ['largest', 'customers', 'location', 'servicing', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.21658328022566
# ['largest', 'customers', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -37.22814268775646
# ['largest', 'consumer', 'location', 'servicing', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -37.22977983888417
# ['largest', 'customers', 'site', 'services', 'for', 'to', 'bypass', 'that', 'for', 'makes'] -37.233544541320995
# ['biggest', 'customers', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.23425059254235
# ['largest', 'consumer', 'location', 'services', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -37.23477389143457
# ['biggest', 'consumer', 'site', 'serving', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -37.23656066860964
# ['biggest', 'consumer', 'location', 'services', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -37.23890536178615
# ['largest', 'consumer', 'site', 'servicing', 'for', 'from', 'bypass', 'that', 'the', 'makes'] -37.24133924641497
# ['largest', 'customers', 'site', 'servicing', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -37.24174142378875
# ['biggest', 'customers', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -37.245810000073135
# ['largest', 'consumer', 'site', 'services', 'via', 'from', 'prevent', 'that', 'the', 'makes'] -37.246333298965354
# ['largest', 'consumer', 'location', 'serving', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -37.2471772229906
# ['biggest', 'consumer', 'location', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -37.24744715120086
# ['biggest', 'consumer', 'site', 'services', 'at', 'to', 'bypass', 'that', 'the', 'makes'] -37.250464769316935
# ['largest', 'customers', 'location', 'services', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.25471806652379
# ['largest', 'consumer', 'site', 'servicing', 'for', 'to', 'prevent', 'that', 'for', 'makes'] -37.25493798244726
# ['largest', 'consumer', 'site', 'serving', 'at', 'to', 'bypass', 'that', 'the', 'makes'] -37.2587366305214
# ['biggest', 'consumer', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'the', 'makes'] -37.25900655873164
# ['biggest', 'guests', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.261790724515194
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'evade', 'that', 'for', 'makes'] -37.26332841001546
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'at', 'makes'] -37.264814826184235
# ['largest', 'consumer', 'location', 'services', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -37.2679146251823
# ['largest', 'consumer', 'location', 'services', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -37.26891899839565
# ['largest', 'guests', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.27006258571966
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'into', 'makes'] -37.27202218338057
# ['finest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.27448109156106
# ['biggest', 'consumer', 'site', 'serve', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.274842082125616
# ['largest', 'consumer', 'location', 'servicing', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -37.27611150765006
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'at', 'makes'] -37.27801138484274
# ['largest', 'customers', 'site', 'services', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -37.27987621008687
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'into', 'makes'] -37.280294044585034
# ['largest', 'consumer', 'site', 'services', 'in', 'from', 'bypass', 'that', 'the', 'makes'] -37.280478405926445
# ['largest', 'customers', 'site', 'services', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -37.286132124290575
# ['largest', 'consumer', 'site', 'services', 'for', 'to', 'prevent', 'that', 'in', 'makes'] -37.293072768745375
# ['largest', 'consumer', 'site', 'services', 'in', 'to', 'prevent', 'that', 'for', 'makes'] -37.29407714195874
# ['largest', 'consumer', 'site', 'services', 'for', 'for', 'prevent', 'that', 'for', 'makes'] -37.29932868294908
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'evade', 'that', 'in', 'makes'] -37.30146319631358
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'becomes'] -37.301501376707776
# ['biggest', 'consumer', 'venue', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.30742269348356
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'becomes'] -37.30977323791223
# ['biggest', 'customers', 'location', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.310398598781234
# ['largest', 'consumer', 'location', 'services', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -37.31092189767344
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'are'] -37.312362371981706
# ['largest', 'consumer', 'site', 'services', 'at', 'of', 'prevent', 'that', 'for', 'makes'] -37.315312484963016
# ['largest', 'consumer', 'venue', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.31569455468802
# ['biggest', 'consumers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.31661776389568
# ['largest', 'customers', 'site', 'servicing', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -37.317889430027634
# ['biggest', 'customers', 'site', 'servicing', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -37.31815935823789
# ['largest', 'customers', 'location', 'services', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -37.32017122913693
# ['biggest', 'customers', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -37.321958006312016
# ['largest', 'consumer', 'site', 'services', 'via', 'from', 'bypass', 'that', 'the', 'makes'] -37.322481305204235
# ['biggest', 'consumer', 'location', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -37.32359515743974
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'from', 'makes'] -37.32378347103392
# ['largest', 'consumers', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.32488962510014
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'are'] -37.32555893064021
# ['largest', 'consumer', 'site', 'servicing', 'for', 'to', 'bypass', 'that', 'for', 'makes'] -37.33108598868614
# ['largest', 'consumer', 'location', 'services', 'for', 'from', 'prevent', 'that', 'the', 'makes'] -37.33336778779544
# ['biggest', 'consumer', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'the', 'makes'] -37.33515456497052
# ['biggest', 'customers', 'site', 'serving', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -37.33555674234432
# ['largest', 'consumer', 'site', 'services', 'via', 'to', 'prevent', 'that', 'for', 'makes'] -37.33608004123653
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'from', 'makes'] -37.33698002969243
# ['biggest', 'guests', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.337938730754075
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'at', 'makes'] -37.340962832423116
# ['largest', 'guests', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.34621059195854
# ['biggest', 'consumer', 'site', 'serving', 'for', 'to', 'prevent', 'that', 'for', 'makes'] -37.34875330100283
# ['finest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.35062909779994
# ['largest', 'consumer', 'location', 'servicing', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.35225951388894
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'at', 'makes'] -37.35415939108162
# ['largest', 'client', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -37.355537675208126
# ['largest', 'customers', 'site', 'services', 'at', 'to', 'bypass', 'that', 'in', 'makes'] -37.35602421632575
# ['biggest', 'customers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -37.35629414453601
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'evade', 'that', 'for', 'makes'] -37.35714372857102
# ['biggest', 'customers', 'site', 'services', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -37.35729851774937
# ['largest', 'customers', 'site', 'services', 'at', 'for', 'bypass', 'that', 'for', 'makes'] -37.36228013052944
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'at', 'makes'] -37.36235627354938
# ['largest', 'customers', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -37.36456600574046
# ['largest', 'customers', 'site', 'serving', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -37.36557037895382
# ['largest', 'consumer', 'site', 'services', 'for', 'to', 'bypass', 'that', 'in', 'makes'] -37.36922077498426
# ['biggest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -37.369926826205614
# ['largest', 'consumer', 'site', 'services', 'in', 'to', 'bypass', 'that', 'for', 'makes'] -37.37022514819762
# ['largest', 'consumer', 'site', 'services', 'for', 'for', 'bypass', 'that', 'for', 'makes'] -37.37547668918795
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'towards', 'makes'] -37.37592254853561
# ['largest', 'consumer', 'site', 'servicing', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -37.377417657452014
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'becomes'] -37.37764938294666
# ['biggest', 'consumer', 'venue', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.38357069972244
# ['largest', 'consumer', 'site', 'servicing', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -37.38367357165572
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'becomes'] -37.38592124415111
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'are'] -37.38851037822059
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'towards', 'makes'] -37.38911910719412
# ['largest', 'consumer', 'site', 'services', 'at', 'of', 'bypass', 'that', 'for', 'makes'] -37.3914604912019
# ['largest', 'consumer', 'venue', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.39184256092689
# ['biggest', 'consumers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.39276577013456
# ['biggest', 'customers', 'site', 'servicing', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -37.39430736447676
# ['largest', 'customers', 'location', 'services', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -37.39631923537581
# ['biggest', 'customers', 'site', 'services', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -37.39930141702716
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'from', 'makes'] -37.3999314772728
# ['largest', 'consumers', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.40103763133902
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'are'] -37.401706936879094
# ['biggest', 'user', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.40507829571273
# ['largest', 'customers', 'site', 'serving', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -37.40757327823161
# ['largest', 'consumer', 'location', 'services', 'for', 'from', 'bypass', 'that', 'the', 'makes'] -37.40951579403432
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'are'] -37.40990381934685
# ['largest', 'customers', 'location', 'services', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -37.40991797140812
# ['biggest', 'customers', 'site', 'serving', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -37.41170474858319
# ['largest', 'consumer', 'site', 'services', 'via', 'to', 'bypass', 'that', 'for', 'makes'] -37.41222804747541
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'from', 'makes'] -37.41312803593131
# ['largest', 'user', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.41335015691719
# ['largest', 'consumer', 'location', 'servicing', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -37.41771267650208
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'from', 'makes'] -37.421324918399065
# ['largest', 'customers', 'site', 'services', 'at', 'to', 'prevent', 'that', 'the', 'makes'] -37.4214773789389
# ['largest', 'consumer', 'site', 'services', 'at', 'for', 'prevent', 'that', 'in', 'makes'] -37.421808357953836
# ['largest', 'consumer', 'location', 'services', 'for', 'to', 'prevent', 'that', 'for', 'makes'] -37.42311453006663
# ['biggest', 'consumer', 'site', 'serving', 'for', 'to', 'bypass', 'that', 'for', 'makes'] -37.4249013072417
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'evade', 'that', 'for', 'makes'] -37.431504957634814
# ['largest', 'client', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -37.43168568144701
# ['biggest', 'customers', 'site', 'services', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -37.43244215077489
# ['biggest', 'customers', 'site', 'services', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -37.43344652398824
# ['largest', 'consumer', 'site', 'services', 'for', 'to', 'prevent', 'that', 'the', 'makes'] -37.43467393759741
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'at', 'makes'] -37.43850427978826
# ['largest', 'client', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.439882563914765
# ['biggest', 'customers', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -37.44063903324265
# ['largest', 'customers', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -37.44071401197934
# ['largest', 'customers', 'site', 'serving', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -37.4417183851927
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'into', 'makes'] -37.44303479300254
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'evade', 'that', 'the', 'makes'] -37.4430643651656
# ['largest', 'customers', 'site', 'serve', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.445854691747584
# ['biggest', 'consumer', 'location', 'serving', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.446074832444495
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'in', 'are'] -37.44803860564497
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'towards', 'makes'] -37.452070554774494
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'these', 'for', 'makes'] -37.45259844912914
# ['largest', 'consumer', 'site', 'servicing', 'at', 'to', 'bypass', 'that', 'in', 'makes'] -37.453565663690895
# ['biggest', 'consumer', 'site', 'servicing', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -37.453835591901154
# ['biggest', 'consumer', 'site', 'servicing', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -37.454839965114516
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'at', 'makes'] -37.45617159210495
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'into', 'makes'] -37.456231351661046
# ['largest', 'consumer', 'site', 'serve', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -37.45905125040609
# ['largest', 'consumer', 'site', 'servicing', 'at', 'for', 'bypass', 'that', 'for', 'makes'] -37.45982157789459
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'these', 'for', 'makes'] -37.46087031033359
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'towards', 'makes'] -37.465267113433
# ['biggest', 'consumer', 'site', 'serving', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -37.471232976007585
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'towards', 'makes'] -37.47346399590076
# ['biggest', 'customers', 'site', 'services', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -37.47544942326603
# ['biggest', 'consumer', 'site', 'serving', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -37.477488890211276
# ['largest', 'client', 'site', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -37.47801735021288
# ['biggest', 'user', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.48122630195161
# ['largest', 'customers', 'site', 'serving', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -37.48372128447049
# ...
# ['finest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -37.9650837866575
# ['biggest', 'consumer', 'site', 'serve', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -37.96544477722206
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'these', 'for', 'makes'] -37.96547705997449
# ['largest', 'consumer', 'location', 'servicing', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -37.9667142027465
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'these', 'for', 'makes'] -37.967263837149574
# ['largest', 'consumer', 'location', 'servicing', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -37.967718575959864
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'at', 'makes'] -37.9690502029503
# ['largest', 'customers', 'site', 'services', 'for', 'to', 'prevent', 'that', 'in', 'makes'] -37.97047890518331
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'into', 'makes'] -37.97082176094479
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'into', 'makes'] -37.97089673968148
# ['largest', 'consumer', 'site', 'serving', 'at', 'to', 'evade', 'that', 'for', 'makes'] -37.97132848921834
# ['largest', 'customers', 'site', 'services', 'in', 'to', 'prevent', 'that', 'for', 'makes'] -37.97148327839669
# ['biggest', 'consumer', 'site', 'serving', 'via', 'from', 'prevent', 'that', 'in', 'makes'] -37.97349503247197
# ['biggest', 'consumer', 'location', 'services', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -37.97583972564847
# ['largest', 'customers', 'site', 'services', 'for', 'for', 'prevent', 'that', 'for', 'makes'] -37.97673481938702
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'these', 'the', 'makes'] -37.97703646750527
# ['largest', 'customers', 'site', 'services', 'at', 'from', 'evade', 'that', 'in', 'makes'] -37.978869332751515
# ['biggest', 'customers', 'site', 'services', 'at', 'from', 'prevent', 'that', 'for', 'becomes'] -37.978907513145714
# ['largest', 'consumer', 'site', 'servicing', 'in', 'from', 'prevent', 'that', 'the', 'makes'] -37.97927798349065
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'of', 'makes'] -37.979814869844304
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'towards', 'makes'] -37.97985752271674
# ['biggest', 'consumer', 'location', 'services', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -37.982095639852176
# ['largest', 'consumer', 'location', 'serving', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -37.98411158685293
# ['biggest', 'client', 'site', 'services', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.984410877028864
# ['biggest', 'customers', 'venue', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.9848288299215
# ['largest', 'customers', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'becomes'] -37.98717937435017
# ['largest', 'customers', 'location', 'services', 'via', 'from', 'bypass', 'that', 'for', 'makes'] -37.98832803411139
# ['largest', 'consumer', 'location', 'serving', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -37.990367501056625
# ['largest', 'consumer', 'site', 'services', 'at', 'to', 'bypass', 'that', 'for', 'becomes'] -37.99183414359396
# ['largest', 'consumer', 'site', 'services', 'for', 'from', 'evade', 'that', 'in', 'makes'] -37.99206589141002
# ['biggest', 'consumer', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'becomes'] -37.99210407180422
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'represents'] -37.992489378110285
# ['largest', 'client', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -37.99268273823331
# ['largest', 'customers', 'site', 'services', 'at', 'of', 'prevent', 'that', 'for', 'makes'] -37.992718621400954
# ['largest', 'consumer', 'site', 'services', 'in', 'from', 'evade', 'that', 'for', 'makes'] -37.993070264623384
# ['largest', 'customers', 'venue', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -37.99310069112596
# ['biggest', 'consumer', 'site', 'services', 'at', 'for', 'prevent', 'that', 'the', 'makes'] -37.99365504738296
# ['largest', 'user', 'location', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -37.994104912796956
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'gets'] -37.99640295531183
# ['largest', 'consumer', 'venue', 'services', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -37.997755460369746
# ['biggest', 'consumer', 'venue', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -37.998025388580004
# ['largest', 'customers', 'site', 'services', 'via', 'from', 'bypass', 'that', 'the', 'makes'] -37.99988744164217
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'becomes'] -38.00037593300868
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'represents'] -38.00076123931474
# ['biggest', 'customers', 'location', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -38.00100129387768
# ['largest', 'consumer', 'site', 'serving', 'at', 'for', 'prevent', 'that', 'the', 'makes'] -38.00192690858741
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'are'] -38.00296506707815
# ['largest', 'user', 'site', 'services', 'at', 'from', 'bypass', 'that', 'the', 'makes'] -38.00566432032775
# ['largest', 'consumer', 'location', 'services', 'in', 'from', 'prevent', 'that', 'in', 'makes'] -38.00585336225798
# ['largest', 'consumer', 'site', 'services', 'for', 'of', 'prevent', 'that', 'for', 'makes'] -38.00591518005946
# ['largest', 'consumer', 'venue', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -38.00629724978447
# ['largest', 'consumers', 'site', 'services', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -38.00695053078188
# ['biggest', 'consumers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -38.00722045899212
# ['biggest', 'consumer', 'site', 'serving', 'in', 'from', 'bypass', 'that', 'in', 'makes'] -38.007640139433065
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'for', 'are'] -38.00832588754331
# ['largest', 'customers', 'site', 'servicing', 'for', 'to', 'bypass', 'that', 'for', 'makes'] -38.00849212512408
# ['largest', 'consumer', 'location', 'servicing', 'via', 'from', 'prevent', 'that', 'for', 'makes'] -38.009721475237654
# ['largest', 'customers', 'location', 'services', 'for', 'from', 'prevent', 'that', 'the', 'makes'] -38.010773924233376
# ['biggest', 'consumer', 'site', 'serve', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -38.011776445987934
# ['biggest', 'customers', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'the', 'makes'] -38.01256070140846
# ['largest', 'customers', 'site', 'services', 'via', 'to', 'prevent', 'that', 'for', 'makes'] -38.01348617767448
# ['biggest', 'consumer', 'location', 'servicing', 'at', 'to', 'bypass', 'that', 'for', 'makes'] -38.013852945589235
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'from', 'makes'] -38.01438616613038
# ['largest', 'consumers', 'site', 'serving', 'for', 'from', 'prevent', 'that', 'for', 'makes'] -38.015492320196586
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'are'] -38.01659774874777
# ['largest', 'user', 'site', 'services', 'at', 'to', 'prevent', 'that', 'for', 'makes'] -38.019263056360046
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'from', 'makes'] -38.01974698659552
# ['biggest', 'consumer', 'site', 'services', 'at', 'from', 'prevent', 'that', 'the', 'are'] -38.01988529507409
# ['largest', 'consumer', 'site', 'servicing', 'via', 'from', 'prevent', 'that', 'the', 'makes'] -38.02128088276844
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'to', 'bypass', 'that', 'the', 'makes'] -38.02541235312002
# ['biggest', 'customers', 'site', 'serving', 'for', 'to', 'prevent', 'that', 'for', 'makes'] -38.02615943744077
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'from', 'makes'] -38.028018847799984
# ['finest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -38.028035234237876
# ['largest', 'consumer', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'the', 'are'] -38.02815715627855
# ['biggest', 'guests', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -38.02854142585052
# ['largest', 'customers', 'location', 'servicing', 'at', 'from', 'bypass', 'that', 'in', 'makes'] -38.029665650326876
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'bypass', 'that', 'at', 'makes'] -38.03156552751956
# ['biggest', 'customers', 'site', 'serving', 'at', 'from', 'evade', 'that', 'for', 'makes'] -38.034549865008955
# ['largest', 'consumer', 'site', 'services', 'via', 'from', 'evade', 'that', 'for', 'makes'] -38.035073163901174
# ['biggest', 'consumer', 'site', 'services', 'at', 'in', 'prevent', 'that', 'for', 'makes'] -38.03633188102131
# ['biggest', 'guests', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -38.03673830831828
# ['largest', 'guests', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -38.03681328705498
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'bypass', 'that', 'at', 'makes'] -38.03692634798472
# ['biggest', 'client', 'location', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -38.03830463211122
# ['largest', 'customers', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'at', 'makes'] -38.03976240998732
# ['finest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -38.04123179289638
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'bypass', 'these', 'for', 'makes'] -38.04162506621337
# ['largest', 'consumer', 'location', 'servicing', 'for', 'from', 'bypass', 'that', 'in', 'makes'] -38.04286220898538
# ['largest', 'consumer', 'location', 'servicing', 'in', 'from', 'bypass', 'that', 'for', 'makes'] -38.043866582198746
# ['largest', 'consumer', 'site', 'serving', 'at', 'in', 'prevent', 'that', 'for', 'makes'] -38.044603742225775
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'bypass', 'that', 'at', 'makes'] -38.04519820918918
# ['largest', 'client', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -38.04657649331568
# ['largest', 'customers', 'site', 'services', 'for', 'to', 'bypass', 'that', 'in', 'makes'] -38.046626911422194
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'bypass', 'that', 'into', 'makes'] -38.046969767183654
# ['biggest', 'customers', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -38.04733296264355
# ['largest', 'customers', 'site', 'services', 'in', 'to', 'bypass', 'that', 'for', 'makes'] -38.04763128463556
# ['biggest', 'consumer', 'site', 'serving', 'for', 'from', 'evade', 'that', 'for', 'makes'] -38.04774642366746
# ['largest', 'consumer', 'location', 'services', 'via', 'from', 'prevent', 'that', 'in', 'makes'] -38.04785626153577
# ['finest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -38.04942867536414
# ['biggest', 'consumer', 'site', 'serving', 'via', 'from', 'bypass', 'that', 'in', 'makes'] -38.049643038710855
# ['biggest', 'client', 'site', 'services', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -38.049864039642
# ['biggest', 'consumer', 'location', 'services', 'at', 'to', 'bypass', 'that', 'in', 'makes'] -38.05198773188735
# ['largest', 'customers', 'site', 'services', 'for', 'for', 'bypass', 'that', 'for', 'makes'] -38.0528828256259
# ['largest', 'consumer', 'site', 'servicing', 'for', 'from', 'prevent', 'that', 'at', 'makes'] -38.052958968645825
# ['largest', 'consumer', 'site', 'services', 'at', 'from', 'bypass', 'these', 'the', 'makes'] -38.05318447374415
# ['largest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'of', 'makes'] -38.0541760989081
# ['largest', 'customers', 'site', 'servicing', 'at', 'to', 'prevent', 'that', 'in', 'makes'] -38.05482379388995
# ['biggest', 'customers', 'site', 'services', 'at', 'from', 'bypass', 'that', 'for', 'becomes'] -38.05505551938459
# ['largest', 'consumer', 'site', 'servicing', 'in', 'from', 'bypass', 'that', 'the', 'makes'] -38.05542598972953
# ['biggest', 'consumer', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'of', 'makes'] -38.055962876083186
# ['largest', 'client', 'site', 'serving', 'at', 'from', 'prevent', 'that', 'the', 'makes'] -38.058135900846466
# ['biggest', 'consumer', 'location', 'services', 'at', 'for', 'bypass', 'that', 'for', 'makes'] -38.05824364609104
# ['largest', 'consumer', 'location', 'serving', 'at', 'to', 'bypass', 'that', 'in', 'makes'] -38.060259593091814
# ['biggest', 'consumer', 'location', 'serving', 'for', 'from', 'prevent', 'that', 'in', 'makes'] -38.06052952130206
# ['biggest', 'customers', 'venue', 'services', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -38.06097683616038
# ['largest', 'customers', 'site', 'servicing', 'at', 'for', 'prevent', 'that', 'for', 'makes'] -38.06107970809366
# ['biggest', 'consumer', 'location', 'serving', 'in', 'from', 'prevent', 'that', 'for', 'makes'] -38.06153389451542
# ['biggest', 'consumer', 'site', 'services', 'at', 'to', 'prevent', 'that', 'at', 'makes'] -38.06208449154781
# ['largest', 'customers', 'site', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'becomes'] -38.06332738058905
# ['largest', 'consumer', 'location', 'serving', 'at', 'for', 'bypass', 'that', 'for', 'makes'] -38.066515507295506
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'prevent', 'that', 'towards', 'makes'] -38.06652524363207
# ['largest', 'consumer', 'site', 'services', 'at', 'to', 'prevent', 'these', 'for', 'makes'] -38.066783209776446
# ['biggest', 'consumer', 'spot', 'services', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -38.06683815355743
# ['largest', 'consumer', 'site', 'servicing', 'for', 'to', 'prevent', 'that', 'in', 'makes'] -38.06802035254846
# ['biggest', 'consumer', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'becomes'] -38.068252078043095
# ['largest', 'customers', 'site', 'services', 'at', 'of', 'bypass', 'that', 'for', 'makes'] -38.068866627639835
# ['largest', 'consumer', 'site', 'servicing', 'in', 'to', 'prevent', 'that', 'for', 'makes'] -38.069024725761835
# ['largest', 'customers', 'venue', 'serving', 'at', 'from', 'bypass', 'that', 'for', 'makes'] -38.06924869736484
# ['biggest', 'consumer', 'site', 'services', 'at', 'for', 'bypass', 'that', 'the', 'makes'] -38.06980305362184
# ['largest', 'consumer', 'site', 'serving', 'at', 'to', 'prevent', 'that', 'at', 'makes'] -38.07035635275227
# ['biggest', 'consumer', 'location', 'services', 'at', 'from', 'prevent', 'that', 'towards', 'makes'] -38.071886064097214
# ['biggest', 'consumer', 'site', 'serving', 'in', 'from', 'prevent', 'that', 'the', 'makes'] -38.0730933020462
# ['biggest', 'consumer', 'venue', 'services', 'for', 'from', 'bypass', 'that', 'for', 'makes'] -38.074173394818885
# ['largest', 'consumer', 'site', 'servicing', 'for', 'for', 'prevent', 'that', 'for', 'makes'] -38.074276266752165
# ['biggest', 'guests', 'site', 'services', 'at', 'from', 'prevent', 'that', 'in', 'makes'] -38.07487309461639
# ['largest', 'consumer', 'spot', 'serving', 'at', 'from', 'prevent', 'that', 'for', 'makes'] -38.07511001476189
# ['largest', 'consumer', 'site', 'servicing', 'at', 'from', 'evade', 'that', 'in', 'makes'] -38.07641078011666
# ['biggest', 'consumer', 'site', 'servicing', 'at', 'from', 'prevent', 'that', 'for', 'becomes'] -38.07644896051086
# ['largest', 'consumer', 'site', 'serving', 'for', 'from', 'bypass', 'that', 'for', 'becomes'] -38.07652393924756
# ['largest', 'consumer', 'site', 'serving', 'at', 'for', 'bypass', 'that', 'the', 'makes'] -38.07807491482629
# ['largest', 'customers', 'site', 'services', 'for', 'from', 'bypass', 'that', 'for', 'are'] -38.07911307331703
# ['largest', 'consumer', 'location', 'serving', 'at', 'from', 'prevent', 'that', 'towards', 'makes'] -38.08015792530168

# %%
perturb_idxes, all_paths
# Out:
# ([6, 7, 9, 8, 3, 25, 24, 1, 23, 2],
#  [(-34.74495742232332,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-34.8211054285622,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.17520294290041,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.183474804104875,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.251350949139294,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.25962281034375,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.42236355876126,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.43556011741977,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.49851156500013,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.511708123658636,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.51990500612641,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.55803979242452,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-35.596053012365275,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.613720324681964,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.634187798663405,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-35.68808155374576,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.689868330920845,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.69964096127654,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-35.76422955998464,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.775788967515425,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-35.78938770354773,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.85260907933835,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.86088094054281,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.8655357097866,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.86580563799686,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.87407749920132,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.92875708557723,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.937028946781695,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.94195364423574,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.950150526703496,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-35.9502255054402,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-35.98828531300161,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-35.996557174206075,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.02629853294238,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.06443331924049,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.072705180444956,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.11296625385771,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.11832707432286,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.12659893552731,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.129886481853646,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.138158343058095,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.18911426009659,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.19447508056173,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.197311142564345,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.20274694176619,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.20603448809253,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.21050770122285,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.214306349296976,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.21963322412482,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.22790508532928,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.23544592886246,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.24864248752097,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.24964686073433,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.27345914880323,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.28665570746173,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.2911264611199,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.29164976001212,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.2957812303637,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.304053091568164,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.30432301977841,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.31159393510134,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.32479049375985,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.32579486697321,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.33298737622761,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.3654876901837,
#    ['largest',
#     'customers',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.36727446735878,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.367797766251,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.37704709771448,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.378684248842205,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.38047102601729,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.39024365637299,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.40913538246649,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.42680269478316,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.44163569642258,
#    ['largest',
#     'customers',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.45319510395336,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.45483225508109,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.463029137548844,
#    ['largest',
#     'consumer',
#     'location',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.46639166261187,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.46679383998567,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.47458854507963,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.479990398644176,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.488380826212364,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-36.50116392384696,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.502950701022044,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.539177143787725,
#    ['largest',
#     'consumer',
#     'location',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.54294184622455,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.543211774434795,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.55073655131851,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.55148363563926,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.55613840488306,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.556844456104415,
#    ['biggest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.564335287350815,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.5684038636352,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.57731193008584,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.5874086897463,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'at',
#     'makes']),
#   (-36.60247007364893,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.60872598785262,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'for',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.619359780673676,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.62755666314143,
#    ['biggest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.62763164187814,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.632992462343296,
#    ['biggest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.63495623554377,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'are']),
#   (-36.640483293589696,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.64075322179994,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.642765092698994,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.64455186987408,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.64637733459598,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'from',
#     'makes']),
#   (-36.658150605906386,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.66355669598518,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'at',
#     'makes']),
#   (-36.66493498011168,
#    ['largest',
#     'client',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.66569144943955,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.67396331064401,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.67861807988781,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.678888008098056,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.67989238131142,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.684873994091504,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'for',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.68715986930252,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.68816424251588,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.698516412097675,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'towards',
#     'makes']),
#   (-36.703704669380315,
#    ['biggest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.71110424178265,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'are']),
#   (-36.71690122803882,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.718913098937875,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.72189528058921,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.72252534083486,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'from',
#     'makes']),
#   (-36.73016714179367,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.73251183497018,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.73429861214525,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.74108298635056,
#    ['largest',
#     'client',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.74183945567843,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.74407124250095,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.750111316882894,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.75503601433694,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.7560403875503,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.763232896804695,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.7633078755414,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.76431224875476,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.7656286565646,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'into',
#     'makes']),
#   (-36.76844855530965,
#    ['largest',
#     'consumer',
#     'site',
#     'serve',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.774664418336556,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'towards',
#     'makes']),
#   (-36.7957332107608,
#    ['biggest',
#     'customers',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.79804328682809,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.804005071965264,
#    ['largest',
#     'customers',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.80631514803255,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.807292618291584,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.80865984120905,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.80892976941931,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.81556447949605,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.81720163062377,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.82021924873983,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.82048917695009,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.82876103815455,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.831545203938106,
#    ['largest',
#     'guests',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.839380903043576,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-36.84177666280348,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'into',
#     'makes']),
#   (-36.844596561548514,
#    ['largest',
#     'consumer',
#     'site',
#     'serve',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.87125585613068,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'becomes']),
#   (-36.87188121699968,
#    ['biggest',
#     'customers',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.87717717290646,
#    ['largest',
#     'consumer',
#     'venue',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.88015307820413,
#    ['largest',
#     'customers',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.883440624530465,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.88507777565819,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.88637224331859,
#    ['largest',
#     'consumers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.88791383766079,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.89171248573493,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.89327465812595,
#    ['biggest',
#     'consumer',
#     'location',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.89334963686264,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.89663718318897,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.89703936056277,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.90483406565673,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-36.904909044393435,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.90531122176722,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.90769321017697,
#    ['largest',
#     'guests',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.91023591922128,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.91850778042573,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.918626346789466,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-36.926048623958906,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.92689820799393,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-36.92705299717227,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.93140944442406,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.939681305628525,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-36.94740386236956,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'becomes']),
#   (-36.95332517914534,
#    ['largest',
#     'consumer',
#     'venue',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.96252024955746,
#    ['largest',
#     'consumers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.96406184389967,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.96905589645006,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.96942266436483,
#    ['biggest',
#     'consumer',
#     'location',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.97318736680164,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.97483277513564,
#    ['largest',
#     'user',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.98098207189561,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-36.9814592280061,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.98172915621636,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.986383925460146,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-36.99458080792792,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-36.99465578666461,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.00219663019779,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.00320100341115,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.007557450662944,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.010393512665544,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.01582931186741,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.017654210323386,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'at',
#     'makes']),
#   (-37.02235292855204,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'these',
#     'for',
#     'makes']),
#   (-37.02359007132405,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.02459444453741,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.02592607152785,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'at',
#     'makes']),
#   (-37.03271559422602,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.038971508429725,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'for',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.04098745543048,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.04520390268894,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.04724336963419,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'for',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.05098078137452,
#    ['largest',
#     'user',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.05609038528016,
#    ['largest',
#     'customers',
#     'location',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.05787716245523,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.06272923083553,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.065201756120864,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'are']),
#   (-37.066597343815204,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.06764979281094,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.070728814166785,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.07301061327608,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.07347361732532,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'are']),
#   (-37.076622855173085,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'from',
#     'makes']),
#   (-37.081282474480545,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.08489471637753,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'from',
#     'makes']),
#   (-37.086541518904426,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.09380221656227,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'at',
#     'makes']),
#   (-37.09518050068877,
#    ['biggest',
#     'client',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.09850093479092,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'these',
#     'for',
#     'makes']),
#   (-37.09973807756293,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.100742450776295,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.10207407776673,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'at',
#     'makes']),
#   (-37.10345236189323,
#    ['largest',
#     'client',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.104208831221115,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.10473213011332,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.1088636004649,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.111051967485665,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'of',
#     'makes']),
#   (-37.115119514668606,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'for',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.11713546166936,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.11740538987962,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.118409763092984,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.123391375873055,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'for',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.12876193267478,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'towards',
#     'makes']),
#   (-37.132238391519024,
#    ['largest',
#     'customers',
#     'location',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.137033793879226,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'towards',
#     'makes']),
#   (-37.13887723707441,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.140435273986796,
#    ['largest',
#     'customers',
#     'location',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.141349762359745,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'are']),
#   (-37.142745350054085,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.14379779904982,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-37.149158619514964,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-37.1496216235642,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'are']),
#   (-37.15199468151758,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.152770861411966,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'from',
#     'makes']),
#   (-37.1536318326453,
#    ['largest',
#     'consumer',
#     'location',
#     'servicing',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.157396535082114,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.15743048071943,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-37.160412662370774,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.161042722616415,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'from',
#     'makes']),
#   (-37.16275735554727,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.165191240176085,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.165786962650316,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-37.171029216751734,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.17132850692765,
#    ['biggest',
#     'client',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.17431676307805,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.17857006028491,
#    ['largest',
#     'customers',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.17898352130882,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-37.179600368132114,
#    ['largest',
#     'client',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.180356837459996,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.1808801363522,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.182588624282516,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.187199973724546,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'of',
#     'makes']),
#   (-37.19176661894342,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-37.19277099215678,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.1935533961185,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.19455776933185,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.19587417714169,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'into',
#     'makes']),
#   (-37.198694075886735,
#    ['biggest',
#     'consumer',
#     'site',
#     'serve',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.20414603834615,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'into',
#     'makes']),
#   (-37.204330399687564,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.20490993891366,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'towards',
#     'makes']),
#   (-37.21318180011811,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'towards',
#     'makes']),
#   (-37.21658328022566,
#    ['largest',
#     'customers',
#     'location',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.22814268775646,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-37.22977983888417,
#    ['largest',
#     'consumer',
#     'location',
#     'servicing',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.233544541320995,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.23425059254235,
#    ['biggest',
#     'customers',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.23477389143457,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.23656066860964,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.23890536178615,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.24133924641497,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-37.24174142378875,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.245810000073135,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.246333298965354,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.2471772229906,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.24744715120086,
#    ['biggest',
#     'consumer',
#     'location',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.250464769316935,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-37.25471806652379,
#    ['largest',
#     'customers',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.25493798244726,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.2587366305214,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-37.25900655873164,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-37.261790724515194,
#    ['biggest',
#     'guests',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.26332841001546,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-37.264814826184235,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'at',
#     'makes']),
#   (-37.2679146251823,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-37.26891899839565,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-37.27006258571966,
#    ['largest',
#     'guests',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
# ...
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-37.99988744164217,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-38.00037593300868,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'becomes']),
#   (-38.00076123931474,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'represents']),
#   (-38.00100129387768,
#    ['biggest',
#     'customers',
#     'location',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.00192690858741,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'for',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-38.00296506707815,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'are']),
#   (-38.00566432032775,
#    ['largest',
#     'user',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-38.00585336225798,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-38.00591518005946,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'of',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.00629724978447,
#    ['largest',
#     'consumer',
#     'venue',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.00695053078188,
#    ['largest',
#     'consumers',
#     'site',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.00722045899212,
#    ['biggest',
#     'consumers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.007640139433065,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-38.00832588754331,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'are']),
#   (-38.00849212512408,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'for',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.009721475237654,
#    ['largest',
#     'consumer',
#     'location',
#     'servicing',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.010773924233376,
#    ['largest',
#     'customers',
#     'location',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-38.011776445987934,
#    ['biggest',
#     'consumer',
#     'site',
#     'serve',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-38.01256070140846,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-38.01348617767448,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'via',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.013852945589235,
#    ['biggest',
#     'consumer',
#     'location',
#     'servicing',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.01438616613038,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'from',
#     'makes']),
#   (-38.015492320196586,
#    ['largest',
#     'consumers',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.01659774874777,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'are']),
#   (-38.019263056360046,
#    ['largest',
#     'user',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.01974698659552,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'from',
#     'makes']),
#   (-38.01988529507409,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'are']),
#   (-38.02128088276844,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-38.02541235312002,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-38.02615943744077,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'for',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.028018847799984,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'from',
#     'makes']),
#   (-38.028035234237876,
#    ['finest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.02815715627855,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'are']),
#   (-38.02854142585052,
#    ['biggest',
#     'guests',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.029665650326876,
#    ['largest',
#     'customers',
#     'location',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-38.03156552751956,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'at',
#     'makes']),
#   (-38.034549865008955,
#    ['biggest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-38.035073163901174,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'via',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-38.03633188102131,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'in',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.03673830831828,
#    ['biggest',
#     'guests',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.03681328705498,
#    ['largest',
#     'guests',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.03692634798472,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'at',
#     'makes']),
#   (-38.03830463211122,
#    ['biggest',
#     'client',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.03976240998732,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'at',
#     'makes']),
#   (-38.04123179289638,
#    ['finest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.04162506621337,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'these',
#     'for',
#     'makes']),
#   (-38.04286220898538,
#    ['largest',
#     'consumer',
#     'location',
#     'servicing',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-38.043866582198746,
#    ['largest',
#     'consumer',
#     'location',
#     'servicing',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.044603742225775,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'in',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.04519820918918,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'at',
#     'makes']),
#   (-38.04657649331568,
#    ['largest',
#     'client',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.046626911422194,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'to',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-38.046969767183654,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'into',
#     'makes']),
#   (-38.04733296264355,
#    ['biggest',
#     'customers',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-38.04763128463556,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'in',
#     'to',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.04774642366746,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'evade',
#     'that',
#     'for',
#     'makes']),
#   (-38.04785626153577,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'via',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-38.04942867536414,
#    ['finest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.049643038710855,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'via',
#     'from',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-38.049864039642,
#    ['biggest',
#     'client',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-38.05198773188735,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-38.0528828256259,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'for',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.052958968645825,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'at',
#     'makes']),
#   (-38.05318447374415,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'these',
#     'the',
#     'makes']),
#   (-38.0541760989081,
#    ['largest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'of',
#     'makes']),
#   (-38.05482379388995,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-38.05505551938459,
#    ['biggest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'becomes']),
#   (-38.05542598972953,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'in',
#     'from',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-38.055962876083186,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'of',
#     'makes']),
#   (-38.058135900846466,
#    ['largest',
#     'client',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-38.05824364609104,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'for',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.060259593091814,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'to',
#     'bypass',
#     'that',
#     'in',
#     'makes']),
#   (-38.06052952130206,
#    ['biggest',
#     'consumer',
#     'location',
#     'serving',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-38.06097683616038,
#    ['biggest',
#     'customers',
#     'venue',
#     'services',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.06107970809366,
#    ['largest',
#     'customers',
#     'site',
#     'servicing',
#     'at',
#     'for',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.06153389451542,
#    ['biggest',
#     'consumer',
#     'location',
#     'serving',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.06208449154781,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'at',
#     'makes']),
#   (-38.06332738058905,
#    ['largest',
#     'customers',
#     'site',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'becomes']),
#   (-38.066515507295506,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'for',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.06652524363207,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'prevent',
#     'that',
#     'towards',
#     'makes']),
#   (-38.066783209776446,
#    ['largest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'to',
#     'prevent',
#     'these',
#     'for',
#     'makes']),
#   (-38.06683815355743,
#    ['biggest',
#     'consumer',
#     'spot',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.06802035254846,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'to',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-38.068252078043095,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'becomes']),
#   (-38.068866627639835,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'at',
#     'of',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.069024725761835,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'in',
#     'to',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.06924869736484,
#    ['largest',
#     'customers',
#     'venue',
#     'serving',
#     'at',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.06980305362184,
#    ['biggest',
#     'consumer',
#     'site',
#     'services',
#     'at',
#     'for',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-38.07035635275227,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'to',
#     'prevent',
#     'that',
#     'at',
#     'makes']),
#   (-38.071886064097214,
#    ['biggest',
#     'consumer',
#     'location',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'towards',
#     'makes']),
#   (-38.0730933020462,
#    ['biggest',
#     'consumer',
#     'site',
#     'serving',
#     'in',
#     'from',
#     'prevent',
#     'that',
#     'the',
#     'makes']),
#   (-38.074173394818885,
#    ['biggest',
#     'consumer',
#     'venue',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'makes']),
#   (-38.074276266752165,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'for',
#     'for',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.07487309461639,
#    ['biggest',
#     'guests',
#     'site',
#     'services',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'in',
#     'makes']),
#   (-38.07511001476189,
#    ['largest',
#     'consumer',
#     'spot',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'makes']),
#   (-38.07641078011666,
#    ['largest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'evade',
#     'that',
#     'in',
#     'makes']),
#   (-38.07644896051086,
#    ['biggest',
#     'consumer',
#     'site',
#     'servicing',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'for',
#     'becomes']),
#   (-38.07652393924756,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'becomes']),
#   (-38.07807491482629,
#    ['largest',
#     'consumer',
#     'site',
#     'serving',
#     'at',
#     'for',
#     'bypass',
#     'that',
#     'the',
#     'makes']),
#   (-38.07911307331703,
#    ['largest',
#     'customers',
#     'site',
#     'services',
#     'for',
#     'from',
#     'bypass',
#     'that',
#     'for',
#     'are']),
#   (-38.08015792530168,
#    ['largest',
#     'consumer',
#     'location',
#     'serving',
#     'at',
#     'from',
#     'prevent',
#     'that',
#     'towards',
#     'makes'])])

# %%
def replace_tokens_in_sentence(sentence, indices, replacement_tokens, tokenizer):
    # Tokenize the original sentence
    tokens = tokenizer.tokenize(sentence)
    
    # Replace tokens at specified indices
    for i, index in enumerate(indices):
        tokens[index-1] = replacement_tokens[i]

    # Decode back to sentence
    return tokenizer.decode(tokenizer.convert_tokens_to_ids(tokens))

# Example
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

for score, path in all_paths:
    modified_sentence = replace_tokens_in_sentence(sentence, perturb_idxes, path, tokenizer)  
    
    print(modified_sentence)
# Out:
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes in far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes via far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes in far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest customers services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes via far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes for far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest customers services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes for far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for evade from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes for far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes at far the biggest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere at prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent to employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent for employees there
# that makes for far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that are at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere from prevent from employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere at bypass from employees there
# that makes at far the largest client services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass to employees there
# that makes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes in far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass for employees there
# that makes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes in far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere towards prevent from employees there
# that makes at far the biggest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that are at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes via far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere from bypass from employees there
# that makes via far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes at far the largest client services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent to employees there
# that makes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes in far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes in far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere into prevent from employees there
# that makes at far the largest consumer serve site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere towards bypass from employees there
# that makes at far the biggest customers services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes via far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes via far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes for far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass to employees there
# that makes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest guests services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere into bypass from employees there
# that makes at far the largest consumer serve site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that becomes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest customers services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer services venue in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest customers serving location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes for far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the biggest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest guests services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for evade from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for evade from employees there
# that makes in far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that becomes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer services venue in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes via far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes at far the largest user services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes in far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere at prevent from employees there
# these makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes in far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere at prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent to employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent for employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in prevent to employees there
# that makes via far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent for employees there
# that makes at far the largest user services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest customers services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes in far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that are at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes via far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that are at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere from prevent from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere from prevent from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere at bypass from employees there
# that makes at far the biggest client services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# these makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes in far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere at bypass from employees there
# that makes at far the largest client serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes via far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass to employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere of prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass for employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass to employees there
# that makes for far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes in far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass for employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere towards prevent from employees there
# that makes for far the largest customers services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere towards prevent from employees there
# that makes in far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest customers servicing location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that are at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes via far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that are at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere from bypass from employees there
# that makes for far the largest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes via far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere from bypass from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for evade from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest client services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent to employees there
# that makes at far the largest customers services location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for evade from employees there
# that makes at far the largest client serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes via far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent to employees there
# that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere of bypass from employees there
# that makes for far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes in far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes in far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere into prevent from employees there
# that makes at far the biggest consumer serve site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere into prevent from employees there
# that makes in far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere towards bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere towards bypass from employees there
# that makes at far the largest customers servicing location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes for far the largest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes at far the biggest customers serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes via far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes via far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes via far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass to employees there
# that makes at far the largest customers services location in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# ...
# that represents at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the biggest customers serving location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent for employees there
# that are for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest user services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes in far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes for far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent of employees there
# that makes for far the largest consumer serving venue in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest consumers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes in far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that are at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes via far the largest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest customers services location in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the biggest consumer serve site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes for far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes via far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere from prevent from employees there
# that makes for far the largest consumers serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that are at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest user services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere from prevent from employees there
# that are at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes via far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the bypass to employees there
# that makes for far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere from prevent from employees there
# that makes at far the finest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that are at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes for far the biggest guests services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers servicing location in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere at bypass from employees there
# that makes at far the biggest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for evade from employees there
# that makes via far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for evade from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent in employees there
# that makes at far the biggest guests servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest guests serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere at bypass from employees there
# that makes at far the biggest client services location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere at prevent from employees there
# that makes for far the finest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# these makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes in far the largest consumer servicing location in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for prevent in employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere at bypass from employees there
# that makes at far the largest client serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere in bypass to employees there
# that makes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere into bypass from employees there
# that makes at far the biggest customers serving location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes in far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass to employees there
# that makes for far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for evade from employees there
# that makes via far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the finest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes via far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere in bypass from employees there
# that makes at far the biggest client services site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere in bypass to employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass for employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere at prevent from employees there
# these makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the largest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere of prevent from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere in prevent to employees there
# that becomes at far the biggest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes in far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere the bypass from employees there
# that makes at far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere of bypass from employees there
# that makes at far the largest client serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere for bypass for employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere in bypass to employees there
# that makes for far the biggest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the biggest customers services venue in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent for employees there
# that makes in far the biggest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere at prevent to employees there
# that becomes at far the largest customers serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere for bypass for employees there
# that makes for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere towards prevent from employees there
# these makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the biggest consumer services spot in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere in prevent to employees there
# that becomes for far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass of employees there
# that makes in far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent to employees there
# that makes at far the largest customers serving venue in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the biggest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere the bypass for employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere at prevent to employees there
# that makes at far the biggest consumer services location in the country good selection but sometimes i ll rather pay more elsewhere towards prevent from employees there
# that makes in far the biggest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the prevent from employees there
# that makes for far the biggest consumer services venue in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes for far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent for employees there
# that makes at far the biggest guests services site in the country good selection but sometimes i ll rather pay more elsewhere in prevent from employees there
# that makes at far the largest consumer serving spot in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that makes at far the largest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere in evade from employees there
# that becomes at far the biggest consumer servicing site in the country good selection but sometimes i ll rather pay more elsewhere for prevent from employees there
# that becomes for far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving site in the country good selection but sometimes i ll rather pay more elsewhere the bypass for employees there
# that are for far the largest customers services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
# that makes at far the largest consumer serving location in the country good selection but sometimes i ll rather pay more elsewhere towards prevent from employees there

# %%
# 加载受害模型和tokenizer

black_box_path = "/home/ubuntu/zhc/work/output"
tokenizer = BertTokenizer.from_pretrained(black_box_path)
model = BertForSequenceClassification.from_pretrained(black_box_path)
model.eval()
model.to('cuda')  # if you are using GPU

def predict_sentiment(sentence, model, tokenizer):
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding=True, max_length=512)
    inputs = {k: v.to('cuda') for k, v in inputs.items()}  # Move to GPU if using GPU
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    predicted_class = torch.argmax(logits, dim=1).item()
    return predicted_class

original_sentiment = predict_sentiment(sentence, model, tokenizer)

print(original_sentiment)
# Out:
# 0

# %% [markdown]
# ### 上面的结果 是 负面输出 0

# %%
success = False

for score, path in all_paths:
    modified_sentence = replace_tokens_in_sentence(sentence, indices, path, tokenizer)
    modified_sentiment = predict_sentiment(modified_sentence, model, tokenizer)
    print(modified_sentiment)
    if modified_sentiment != original_sentiment:
        print(f"Attack successful with sentence: {modified_sentence}")
        success = True
        break

if not success:
    print("Attack failed after trying all paths.")
# Out:
# 0
# 1
# Attack successful with sentence: that makes at far the largest consumer services site in the country good selection but sometimes i ll rather pay more elsewhere for bypass from employees there
